# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
from IPython.core.display import HTML 
from IPython.display import Image 
from datetime import datetime
import folium # plotting library
import json

print('Folium installed')
print('Libraries imported.')

CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
address = input("ENTER ADDRESS : \n")
radius = input("Enter radius :\n")
geolocator = Nominatim(timeout=10)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
No_Q = input("Enter number of Queries : ")
import json

data_ice = []
for i in range(int(No_Q)):
    print("{} ".format(i),end="")
    search_query = input("Enter Search Query : ")
    
    print(search_query + ' .... OK!')

    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    #url
    results = requests.get(url).json()
    item = results['response']['venues']
    #print(json.dumps(item, indent=4, sort_keys=True))
    for item_ in item:
        #print(json.dumps(item_, indent=4, sort_keys=True))
        name = item_["name"]
        cat = item_["categories"]
        loc = ', '.join(item_["location"]["formattedAddress"])
        lat_ = item_["location"]["lat"]
        lon_ = item_["location"]["lng"]
        #add = item_["location"]
        #print(name)
        #print(cat)
        #print(loc)
        #print(lat_,"   +   ",lon_)
        data_ice.append((search_query,"{}\n and Location : {}".format(name,loc),lat_,lon_))

    #print(data_ice)    
print("DONE COMPLETED")
"""

Algorithm:
    
    Initialise vertex_list
    
    1. Find the minimum distance for class 1 and append it to vertex list.
    2. For every other class find min distance to vertex_list and add it to vertex_list
    3. find the minimum distance from addition of verteces to the list and add the next node to the list

"""




from math import sin, cos, sqrt, atan2, radians
import random # library for random number generation
import folium # plotting library

# approximate radius of earth in km
R = 6373.0

def ret_dist(lat1,lon1,lat2,lon2):
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    #print("Result:", distance)
    #print("Should be:", 278.546, "km")
    return distance
string_gen = "0123456789abcdef"
def get_random_col():
    # unnecessary stuffs to make the visualization cool
    ret_str = "#"
    for i in range(6):
        ret_str += random.choice(string_gen)
    return ret_str

def Jimut_Wisp_Cluster3_Minimum(map_data):
    MAP_TYPES = ["Mapbox Bright","Stamen Toner","Stamen Terrain","OpenStreetMap","Mapbox Control Room"]
    name_type = int(input(" 0 - Mapbox Bright\n 1 - Stamen Toner\n 2 - Stamen Terrain\n 3 - OpenStreetMap\n 4 - Mapbox Control Room"))
    MAP = folium.Map(location=[latitude, longitude],tiles=MAP_TYPES[name_type], zoom_start=11)

    name=map_data[0][0]
    LEGEND_DATA = []
    full_tree = []
    data_cate = []
    OVER_COL = str(get_random_col())
    FILL_COL = str(get_random_col())
    LEGEND_DATA.append([name,OVER_COL,FILL_COL])
    for item in map_data:
        lat = item[2]
        lng = item[3]
        #print(item," => ")
        if(item[0]!=name):
            OVER_COL = str(get_random_col())
            FILL_COL = str(get_random_col())
            full_tree.append([name,data_cate])
            name=item[0]
            LEGEND_DATA.append([name,OVER_COL,FILL_COL])
            data_cate=[]
            #print("got into first check")
        if(item[0]==name):
            data_cate.append([item[1],lat,lng])
            #print("got into 2nd check")
        label = "cat : {} \n, Name : {}".format(item[0],item[1])
        folium.CircleMarker(
                            [lat, lng],
                            radius=5,
                            popup=label,
                            color=OVER_COL,
                            fill=True,
                            fill_color=FILL_COL,
                            fill_opacity=0.7).add_to(MAP)
    full_tree.append([name,data_cate])
    min_dist_vert = []
    vert_only = []
    for i in full_tree:
        item_class = i[0]
        print(item_class)
        k_dummy=0
        print("i[1:][0] => ",i[1:][0])
        for item in i[1:][0]:
            # the upper class 
            name_point_ = item[0]
            name_lat_ = item[1]
            name_lon_ = item[2]

            final_dist=0
            print("item loop => ",name_point_," == ",name_lat_," == ",name_lon_)
            #
            for k in full_tree:
                # the sub class
                item_class2 = k[0]
                #print("class 2 => ",item_class2)
                if len(min_dist_vert) == 0:
                    if item_class2!=item_class:
                        #print("class 2 ",k)
                        for j in k[1:][0]:
                            name_point = j[0]
                            name_lat = j[1]
                            name_lon = j[2]
                            print(name_point," == ",name_lat," == ",name_lon,end="")
                            dist_from_item = ret_dist(name_lat_,name_lon_,name_lat,name_lon)
                            print(" dist from ",name_point_," to ",name_point," is:=> ",dist_from_item)
                            final_dist += dist_from_item
            if len(min_dist_vert)>0:

                if item_class2 not in vert_only:
                    print("class2 => ",item_class2)
                    print("\n\nmin_dist_vert => ",min_dist_vert)
                    for j in min_dist_vert:
                        name_point = j[0]
                        name_lat = j[1][0]
                        name_lon = j[1][1]
                        print("2nd check => ",name_point," == ",name_lat," == ",name_lon,end="")
                        dist_from_item = ret_dist(name_lat_,name_lon_,name_lat,name_lon)
                        print("[+] dist from ",name_point_," to ",name_point," is:=> ",dist_from_item)
                        final_dist += dist_from_item
            print("Total dist of ",name_point_," is => ",final_dist)

            if k_dummy==1:
                if minimum_dist>=final_dist:
                    minimum_dist = final_dist
                    min_dist_lat = name_lat_
                    min_dist_lon = name_lon_
                    min_dist_name = name_point_
                    print("Minimum => ",min_dist_name,"dist => ",minimum_dist," + ",min_dist_lat," + ",min_dist_lon)
            if k_dummy==0:
                minimum_dist=final_dist
                minimum_dist = final_dist
                min_dist_lat = name_lat_
                min_dist_lon = name_lon_
                min_dist_name = name_point_
                k_dummy=1
                print("dummy set to 1")
            print("$$$$Minimum => ",min_dist_name,"dist => ",minimum_dist," + ",min_dist_lat," + ",min_dist_lon)
        vert_only.append(item_class)
        min_dist_vert.append([min_dist_name,[min_dist_lat,min_dist_lon]])
        print("MIN DIST VERT LIST => ",min_dist_vert)
        
    for i1 in min_dist_vert:
        for j1 in min_dist_vert:
            p1 = i1[1]
            p2 = j1[1]
            print(p1,",",p2)
            folium.PolyLine(locations=[p1, p2], color='red',weight=1.5,opacity=1).add_to(MAP)
    #print(LEGEND_DATA)
    DOTS_HTML = ""
    for item in LEGEND_DATA:
        name_leg = item[0]
        over_leg = item[1]
        fill_leg = item[2]
        DOTS_HTML +="""
            &nbsp; {} &nbsp;
            <svg height="10" width="10">
            <circle cx="5" cy="5" r="4" stroke="{}" stroke-width="3" fill="{}" />
            </svg><br/> """.format(str(name_leg),str(over_leg),str(fill_leg))
    LEGEND_HTML = """
    <center>
    <h1 ><i style="color:#c6ae0d; font face=Arial,Helvetica "> WISP v2.0 </i></h1> 
    </center>
    
    <div id="legend-html" style="position: fixed; background-color: white; 
    bottom: 50px; left: 50px;  
    border:2px solid grey; z-index:9999; font-size:14px;" >&nbsp; 
    <b>Legend <b>
    <br>{}
    </div>
    <div style="position: fixed; 
    bottom: 50px; right: 50px;  
    z-index:9999; font-size:10px;
    "> 
    <b style="color:#f90404" style="align: justified">
        WISP <br/> 
        version: 2.0 <br/>
        &copyJimut Bahan Pal <br/> 
        Author : jimutbahanpal@yahoo.com 
    </b>
    </div>
    <div style="position: fixed; 
    top: 70px; left: 50px;  
    z-index:9999; font-size:15px;
    "> 
    <b style="color:#16842c" style="align: justified">
        Location: {} <br/>
        Lat, Lon: {},{} <br/>
        Radius: {} <br/>
        Date: {} <br/>
    </b>
    </div> 
    """.format(str(DOTS_HTML),address,latitude,longitude,radius,datetime.now().isoformat(timespec='seconds'))
    MAP.get_root().html.add_child(folium.Element(LEGEND_HTML))
    
    return MAP

# %%
MAP = Jimut_Wisp_Cluster3_Minimum(data_ice)
# Out:
#  0 - Mapbox Bright
#  1 - Stamen Toner
#  2 - Stamen Terrain
#  3 - OpenStreetMap
#  4 - Mapbox Control Room3
# pub
# i[1:][0] =>  [['Sams Pub\n and Location : India', 22.558223809925604, 88.34986198355678], ["Floriana (Sam's Pub)\n and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India", 22.55318711175468, 88.35095643997192], ['Super Pub\n and Location : Sudder Street, Kolkata, West Bengal, India', 22.5551789067686, 88.3541154954582], ["Sam's Pub\n and Location : India", 22.55331195527922, 88.35167821299912], ['London Pub\n and Location : Golden Parkk, Chowringhee, India', 22.547619, 88.3497], ['Soda Pub\n and Location : Sambhu Nath Pandit St, Kolkata 700020, West Bengal, India', 22.538066161926018, 88.34548473358153], ['Rishirich Soda Pub\n and Location : Beck Bagan Row, Kolkata 700017, West Bengal, India', 22.540038122836695, 88.36161017417908], ['Olypub\n and Location : 21, Park St, Kolkata 700016, West Bengal, India', 22.55355099631339, 88.35192458139935], ['Rishirich Soda Pub\n and Location : 23A/1/B, Justice Dwarka Nath Rd, Kolkata 700020, West Bengal, India', 22.533329376923408, 88.34760904312134], ['Mags Pubs\n and Location : 12K, Park St, Kolkata 700016, West Bengal, India', 22.553346879251055, 88.35203386257905], ['Advaita Ashrama Publishing House\n and Location : Howrah Station, Hāora 711101, West Bengal, India', 22.5816, 88.3415], ['All India Institute Of Public Health And Hygiene\n and Location : India', 22.578108751676748, 88.36051642383026], ['The Hindustan Publishing Co\n and Location : 15, Bankim Chatterjee St, Kolkata 700073, West Bengal, India', 22.5746054, 88.364707], ['The Frank Anthony Public School\n and Location : 171, Acharya Jagadish Chandra Bose Rd, Kolkata 700014, West Bengal, India', 22.552929494766527, 88.36576223373413], ['Public Service Commission West Bengal\n and Location : 161-A, S. P. Mukherjee Rd, Kolkata 700026, West Bengal, India', 22.51093149916928, 88.34590315818787], ['Future Publishers & Distributors\n and Location : 52D, Beck Bagan Row, Kolkata 700017, West Bengal, India', 22.53813552786315, 88.36517751216888], ['The Ideal Homoeopathic Publishing Co.\n and Location : 81A, Diamond Harbour Rd, Kolkata 700023, West Bengal, India', 22.539037281874425, 88.32740396261215], ['Hahnemann Publishing Co. Private Ltd.\n and Location : Ashutosh Mukherjee Rd, Kolkata 700025, West Bengal, India', 22.531109572390285, 88.34586024284363], ['Army Public School\n and Location : Ballygunge Circular Rd, Kolkata 700019, West Bengal, India', 22.532140200360733, 88.36076259613037], ['Forward Publishers\n and Location : 45B, S. P. Mukherjee Rd, Kolkata 700026, West Bengal, India', 22.5240931699041, 88.34654152393341], ['LLR Public School\n and Location : India', 22.541892, 88.391068], ['Modern Public School\n and Location : 166C, Sarat Bose Rd, Kolkata 700029, West Bengal, India', 22.5192468872466, 88.35211515426636], ['Ananda Publishers Limited\n and Location : 190/2, Rash Behari Ave, Kolkata 700029, West Bengal, India', 22.518305360673185, 88.3591103553772], ['Government of West Bengal  - Public Works Directorate\n and Location : 76, Dr. Deodar Rahaman Road, Kolkata 700033, West Bengal, India', 22.504356, 88.35254]]
# item loop =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678
# Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  ==  22.563550842339577  ==  88.35119247436523 dist from  Sams Pub
#  and Location : India  to  Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  is:=>  0.6080814829304455
# Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  ==  22.55312518463798  ==  88.35262477397919 dist from  Sams Pub
#  and Location : India  to  Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  is:=>  0.6341652881972368
# Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  ==  22.56803262350744  ==  88.35027929628481 dist from  Sams Pub
#  and Location : India  to  Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  is:=>  1.091874412295831
# The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  ==  22.5614816  ==  88.3489535 dist from  Sams Pub
#  and Location : India  to  The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  is:=>  0.37418647756318923
# Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  ==  22.56721660263858  ==  88.35286617279053 dist from  Sams Pub
#  and Location : India  to  Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  is:=>  1.0467831100333982
# Shaw bar
#  and Location : Kolkata, West Bengal, India  ==  22.5649  ==  88.3523 dist from  Sams Pub
#  and Location : India  to  Shaw bar
#  and Location : Kolkata, West Bengal, India  is:=>  0.7836806792898671
# Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  ==  22.56064367858119  ==  88.35164501888916 dist from  Sams Pub
#  and Location : India  to  Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  is:=>  0.325564605001822
# New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  ==  22.56004351018036  ==  88.35196495056152 dist from  Sams Pub
#  and Location : India  to  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  is:=>  0.29602379133090617
# Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  ==  22.57310727237794  ==  88.35158811464137 dist from  Sams Pub
#  and Location : India  to  Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  is:=>  1.6649520500762338
# Bombai Milk Bar
#  and Location : India  ==  22.56653  ==  88.356026 dist from  Sams Pub
#  and Location : India  to  Bombai Milk Bar
#  and Location : India  is:=>  1.1200261962453866
# Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  ==  22.571925  ==  88.353709 dist from  Sams Pub
#  and Location : India  to  Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  is:=>  1.5743753028997873
# Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  ==  22.559567932850594  ==  88.35273742675781 dist from  Sams Pub
#  and Location : India  to  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is:=>  0.3310461852075209
# New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179 dist from  Sams Pub
#  and Location : India  to  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is:=>  0.2893734449398601
# Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652 dist from  Sams Pub
#  and Location : India  to  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is:=>  0.5705118503116864
# Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355 dist from  Sams Pub
#  and Location : India  to  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is:=>  1.8996086923084774
# 1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786 dist from  Sams Pub
#  and Location : India  to  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is:=>  0.13079834684673425
# Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023 dist from  Sams Pub
#  and Location : India  to  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is:=>  0.6657363357416587
# Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202 dist from  Sams Pub
#  and Location : India  to  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is:=>  0.22263588520130667
# Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174 dist from  Sams Pub
#  and Location : India  to  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is:=>  0.2311754517283433
# Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294 dist from  Sams Pub
#  and Location : India  to  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is:=>  0.35190490638373273
# Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  ==  22.553809399418334  ==  88.3516770971553 dist from  Sams Pub
#  and Location : India  to  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  is:=>  0.5252226220485868
# Nagraj Bar
#  and Location : Bengal Club, India  ==  22.55336490115175  ==  88.35094793669646 dist from  Sams Pub
#  and Location : India  to  Nagraj Bar
#  and Location : Bengal Club, India  is:=>  0.5518476490919924
# IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  ==  22.5816  ==  88.3416 dist from  Sams Pub
#  and Location : India  to  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  is:=>  2.73510329954237
# Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  ==  22.551066711460887  ==  88.35397124290466 dist from  Sams Pub
#  and Location : India  to  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  is:=>  0.9010699394608097
# Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  ==  22.552565  ==  88.350703 dist from  Sams Pub
#  and Location : India  to  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  is:=>  0.6353294962164175
# M Bar and Kitchen
#  and Location : India  ==  22.551271548058658  ==  88.35345168984142 dist from  Sams Pub
#  and Location : India  to  M Bar and Kitchen
#  and Location : India  is:=>  0.856716059387882
# Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  ==  22.570218490509358  ==  88.35000157356262 dist from  Sams Pub
#  and Location : India  to  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  is:=>  1.3342433626092465
# The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  ==  22.57159442335056  ==  88.40526765640105 dist from  Sams Pub
#  and Location : India  to  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  is:=>  5.882091691917858
# Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  ==  22.56661118962308  ==  88.35588891639183 dist from  Sams Pub
#  and Location : India  to  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  is:=>  1.1196404699301639
# Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  ==  22.5761994  ==  88.3488699 dist from  Sams Pub
#  and Location : India  to  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  is:=>  2.002016847225537
# Total dist of  Sams Pub
#  and Location : India  is =>  30.755785931964294
# dummy set to 1
# $$$$Minimum =>  Sams Pub
#  and Location : India dist =>  30.755785931964294  +  22.558223809925604  +  88.34986198355678
# item loop =>  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  ==  22.55318711175468  ==  88.35095643997192
# Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  ==  22.563550842339577  ==  88.35119247436523 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  is:=>  1.1530109665871007
# Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  ==  22.55312518463798  ==  88.35262477397919 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  is:=>  0.17151536586126062
# Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  ==  22.56803262350744  ==  88.35027929628481 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  is:=>  1.6527280450110475
# The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  ==  22.5614816  ==  88.3489535 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  is:=>  0.9452569624733609
# Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  ==  22.56721660263858  ==  88.35286617279053 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  is:=>  1.5727791394448598
# Shaw bar
#  and Location : Kolkata, West Bengal, India  ==  22.5649  ==  88.3523 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Shaw bar
#  and Location : Kolkata, West Bengal, India  is:=>  1.3101119357020496
# Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  ==  22.56064367858119  ==  88.35164501888916 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  is:=>  0.8324032295845241
# New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  ==  22.56004351018036  ==  88.35196495056152 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  is:=>  0.7696399734379084
# Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  ==  22.57310727237794  ==  88.35158811464137 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  is:=>  2.2166659302166902
# Bombai Milk Bar
#  and Location : India  ==  22.56653  ==  88.356026 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Bombai Milk Bar
#  and Location : India  is:=>  1.572832153027852
# Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  ==  22.571925  ==  88.353709 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  is:=>  2.1033017994533867
# Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  ==  22.559567932850594  ==  88.35273742675781 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is:=>  0.7329368019857653
# New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is:=>  0.8063386099227047
# Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is:=>  1.0199817294400906
# Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is:=>  2.452322924255155
# 1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is:=>  0.6572864330148979
# Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is:=>  0.19341607313676398
# Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is:=>  0.591124429759287
# Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is:=>  0.5235925280814117
# Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is:=>  0.22026306140636037
# Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  ==  22.553809399418334  ==  88.3516770971553 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  is:=>  0.10134673304626438
# Nagraj Bar
#  and Location : Bengal Club, India  ==  22.55336490115175  ==  88.35094793669646 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Nagraj Bar
#  and Location : Bengal Club, India  is:=>  0.019794766536863143
# IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  ==  22.5816  ==  88.3416 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  is:=>  3.3032487408868993
# Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  ==  22.551066711460887  ==  88.35397124290466 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  is:=>  0.3892761800216161
# Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  ==  22.552565  ==  88.350703 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  is:=>  0.07393282005965973
# M Bar and Kitchen
#  and Location : India  ==  22.551271548058658  ==  88.35345168984142 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  M Bar and Kitchen
#  and Location : India  is:=>  0.3333152384614587
# Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  ==  22.570218490509358  ==  88.35000157356262 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  is:=>  1.8969347582207174
# The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  ==  22.57159442335056  ==  88.40526765640105 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  is:=>  5.9425144160963175
# Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  ==  22.56661118962308  ==  88.35588891639183 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  is:=>  1.5767755326608632
# Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  ==  22.5761994  ==  88.3488699 dist from  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  to  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  is:=>  2.568609714677074
# Total dist of  Floriana (Sam's Pub)
#  and Location : 13, Anandilal Poddar Sarani, Kolkata 700071, West Bengal, India  is =>  37.70325699247021
# $$$$Minimum =>  Sams Pub
#  and Location : India dist =>  30.755785931964294  +  22.558223809925604  +  88.34986198355678
# item loop =>  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  ==  22.5551789067686  ==  88.3541154954582
# Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  ==  22.563550842339577  ==  88.35119247436523 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  is:=>  0.9784169890521582
# Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  ==  22.55312518463798  ==  88.35262477397919 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  is:=>  0.2750121920323076
# Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  ==  22.56803262350744  ==  88.35027929628481 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  is:=>  1.4830240199638736
# The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  ==  22.5614816  ==  88.3489535 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  is:=>  0.8789880295974717
# Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  ==  22.56721660263858  ==  88.35286617279053 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  is:=>  1.3450863918055864
# Shaw bar
#  and Location : Kolkata, West Bengal, India  ==  22.5649  ==  88.3523 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Shaw bar
#  and Location : Kolkata, West Bengal, India  is:=>  1.0972389849498678
# Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  ==  22.56064367858119  ==  88.35164501888916 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  is:=>  0.6586911838216184
# New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  ==  22.56004351018036  ==  88.35196495056152 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  is:=>  0.5844450423570668
# Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  ==  22.57310727237794  ==  88.35158811464137 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  is:=>  2.0109955025613098
# Bombai Milk Bar
#  and Location : India  ==  22.56653  ==  88.356026 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Bombai Milk Bar
#  and Location : India  is:=>  1.2777401727318347
# Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  ==  22.571925  ==  88.353709 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  is:=>  1.8631330709349982
# Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  ==  22.559567932850594  ==  88.35273742675781 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is:=>  0.5082992162288777
# New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is:=>  0.6487044059452053
# Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is:=>  0.7639938050129104
# Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is:=>  2.244801597052551
# 1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is:=>  0.5577655566455579
# Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is:=>  0.28715907844001093
# Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is:=>  0.41892353654746073
# Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is:=>  0.659482707814813
# Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is:=>  0.3819872223075079
# Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  ==  22.553809399418334  ==  88.3516770971553 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  is:=>  0.29316170667322283
# Nagraj Bar
#  and Location : Bengal Club, India  ==  22.55336490115175  ==  88.35094793669646 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Nagraj Bar
#  and Location : Bengal Club, India  is:=>  0.3828626620146669
# IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  ==  22.5816  ==  88.3416 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  is:=>  3.2076654753475866
# Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  ==  22.551066711460887  ==  88.35397124290466 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  is:=>  0.45763876297682526
# Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  ==  22.552565  ==  88.350703 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  is:=>  0.45542464254095283
# M Bar and Kitchen
#  and Location : India  ==  22.551271548058658  ==  88.35345168984142 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  M Bar and Kitchen
#  and Location : India  is:=>  0.43993150206561193
# Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  ==  22.570218490509358  ==  88.35000157356262 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  is:=>  1.7253959684604878
# The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  ==  22.57159442335056  ==  88.40526765640105 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  is:=>  5.5623587988846
# Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  ==  22.56661118962308  ==  88.35588891639183 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  is:=>  1.2845922277265698
# Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  ==  22.5761994  ==  88.3488699 dist from  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  to  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  is:=>  2.3993835121521285
# Total dist of  Super Pub
#  and Location : Sudder Street, Kolkata, West Bengal, India  is =>  35.132303964645644
# $$$$Minimum =>  Sams Pub
#  and Location : India dist =>  30.755785931964294  +  22.558223809925604  +  88.34986198355678
# item loop =>  Sam's Pub
#  and Location : India  ==  22.55331195527922  ==  88.35167821299912
# Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  ==  22.563550842339577  ==  88.35119247436523 dist from  Sam's Pub
#  and Location : India  to  Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  is:=>  1.1399621433035263
# Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  ==  22.55312518463798  ==  88.35262477397919 dist from  Sam's Pub
#  and Location : India  to  Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  is:=>  0.0994284625640508
# Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  ==  22.56803262350744  ==  88.35027929628481 dist from  Sam's Pub
#  and Location : India  to  Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  is:=>  1.643670546043866
# The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  ==  22.5614816  ==  88.3489535 dist from  Sam's Pub
#  and Location : India  to  The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  is:=>  0.950833987074624
# Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  ==  22.56721660263858  ==  88.35286617279053 dist from  Sam's Pub
#  and Location : India  to  Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  is:=>  1.5514179216269808
# Shaw bar
#  and Location : Kolkata, West Bengal, India  ==  22.5649  ==  88.3523 dist from  Sam's Pub
#  and Location : India  to  Shaw bar
#  and Location : Kolkata, West Bengal, India  is:=>  1.2905177375484638
# Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  ==  22.56064367858119  ==  88.35164501888916 dist from  Sam's Pub
#  and Location : India  to  Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  is:=>  0.8155134883295168
# New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  ==  22.56004351018036  ==  88.35196495056152 dist from  Sam's Pub
#  and Location : India  to  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  is:=>  0.749328826216858
# Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  ==  22.57310727237794  ==  88.35158811464137 dist from  Sam's Pub
#  and Location : India  to  Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  is:=>  2.2018492684621758
# Bombai Milk Bar
#  and Location : India  ==  22.56653  ==  88.356026 dist from  Sam's Pub
#  and Location : India  to  Bombai Milk Bar
#  and Location : India  is:=>  1.5365734072771877
# Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  ==  22.571925  ==  88.353709 dist from  Sam's Pub
#  and Location : India  to  Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  is:=>  2.0808077955819866
# Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  ==  22.559567932850594  ==  88.35273742675781 dist from  Sam's Pub
#  and Location : India  to  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is:=>  0.7043062457572711
# New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179 dist from  Sam's Pub
#  and Location : India  to  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is:=>  0.7920560296215647
# Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652 dist from  Sam's Pub
#  and Location : India  to  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is:=>  0.9892918796414867
# Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355 dist from  Sam's Pub
#  and Location : India  to  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is:=>  2.437558225290169
# 1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786 dist from  Sam's Pub
#  and Location : India  to  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is:=>  0.6504369974241443
# Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023 dist from  Sam's Pub
#  and Location : India  to  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is:=>  0.12541896031616126
# Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202 dist from  Sam's Pub
#  and Location : India  to  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is:=>  0.5681404958979382
# Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174 dist from  Sam's Pub
#  and Location : India  to  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is:=>  0.5592186927160038
# Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294 dist from  Sam's Pub
#  and Location : India  to  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is:=>  0.2383447717884915
# Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  ==  22.553809399418334  ==  88.3516770971553 dist from  Sam's Pub
#  and Location : India  to  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  is:=>  0.055330747361187635
# Nagraj Bar
#  and Location : Bengal Club, India  ==  22.55336490115175  ==  88.35094793669646 dist from  Sam's Pub
#  and Location : India  to  Nagraj Bar
#  and Location : Bengal Club, India  is:=>  0.07524719792919353
# IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  ==  22.5816  ==  88.3416 dist from  Sam's Pub
#  and Location : India  to  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  is:=>  3.312379901711663
# Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  ==  22.551066711460887  ==  88.35397124290466 dist from  Sam's Pub
#  and Location : India  to  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  is:=>  0.3432968213151044
# Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  ==  22.552565  ==  88.350703 dist from  Sam's Pub
#  and Location : India  to  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  is:=>  0.1301476519571537
# M Bar and Kitchen
#  and Location : India  ==  22.551271548058658  ==  88.35345168984142 dist from  Sam's Pub
#  and Location : India  to  M Bar and Kitchen
#  and Location : India  is:=>  0.29102799204271645
# Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  ==  22.570218490509358  ==  88.35000157356262 dist from  Sam's Pub
#  and Location : India  to  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  is:=>  1.88838065523566
# The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  ==  22.57159442335056  ==  88.40526765640105 dist from  Sam's Pub
#  and Location : India  to  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  is:=>  5.86814234689565
# Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  ==  22.56661118962308  ==  88.35588891639183 dist from  Sam's Pub
#  and Location : India  to  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  is:=>  1.5412057280473397
# Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  ==  22.5761994  ==  88.3488699 dist from  Sam's Pub
#  and Location : India  to  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  is:=>  2.562056661213007
# Total dist of  Sam's Pub
#  and Location : India  is =>  37.19189158619114
# $$$$Minimum =>  Sams Pub
#  and Location : India dist =>  30.755785931964294  +  22.558223809925604  +  88.34986198355678
# item loop =>  London Pub
#  and Location : Golden Parkk, Chowringhee, India  ==  22.547619  ==  88.3497
# Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  ==  22.563550842339577  ==  88.35119247436523 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Metro Bar & Restaurant
#  and Location : 5, Jawaharlal Nehru Rd, Kolkata 700013, West Bengal, India  is:=>  1.7787154330740547
# Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  ==  22.55312518463798  ==  88.35262477397919 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Bar-B-Q
#  and Location : 43, 47, 55, Park St, Kolkata 700016, West Bengal, India  is:=>  0.6821781160562067
# Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  ==  22.56803262350744  ==  88.35027929628481 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Wilson Bar
#  and Location : Lalit Great Eastern, Kolkata 700069, West Bengal, India  is:=>  2.2713835264140165
# The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  ==  22.5614816  ==  88.3489535 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  The Bar – The Oberoi Grand
#  and Location : The Oberoi Grand, 15, Jawaharlal Nehru Road, Kolkata, West Bengal, India  is:=>  1.5438402593168574
# Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  ==  22.56721660263858  ==  88.35286617279053 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Elfin Bar & Restaurant
#  and Location : 5, Meredith St, Kolkata 700001, West Bengal, India  is:=>  2.203966568051547
# Shaw bar
#  and Location : Kolkata, West Bengal, India  ==  22.5649  ==  88.3523 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Shaw bar
#  and Location : Kolkata, West Bengal, India  is:=>  1.9406284134078646
# Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  ==  22.56064367858119  ==  88.35164501888916 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Barista Lavazza Espresso Bar
#  and Location : New Market St, Kolkata 700013, West Bengal, India  is:=>  1.4624451730633454
# New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  ==  22.56004351018036  ==  88.35196495056152 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India  is:=>  1.4014242669100747
# Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  ==  22.57310727237794  ==  88.35158811464137 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Damurs Bar And Restaurant
#  and Location : Old Court House Corner, Kolkata, West Bengal, India  is:=>  2.8416822865168596
# Bombai Milk Bar
#  and Location : India  ==  22.56653  ==  88.356026 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Bombai Milk Bar
#  and Location : India  is:=>  2.201551270218211
# Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  ==  22.571925  ==  88.353709 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Cecil Bar & Restaurant
#  and Location : 309, B B Ganguly Street,, Kolkata 700012, West Bengal, India  is:=>  2.734734570593763
# Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  ==  22.559567932850594  ==  88.35273742675781 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is:=>  1.365210789760838
# New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is:=>  1.434784868397185
# Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is:=>  1.651866534538765
# Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is:=>  3.0769681535099482
# 1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is:=>  1.280476691835347
# Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is:=>  0.6682802721395896
# Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is:=>  1.2237117919449174
# Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is:=>  1.0612980438322968
# Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294 dist from  London Pub
#  and Location : Golden Parkk, Chowringhee, India  to  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is:=>  0.8350806254206767
# Cha Bar
# ...
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.3310461852075209
# Total dist of  Badshah Bar & Restaurant
#  and Location : 5, Lindsay St, Kolkata 700087, West Bengal, India  is =>  0.3310461852075209
# $$$$Minimum =>  New Cathay Bar and Restaurant
#  and Location : 17, Jawaharlal Nehru Rd, Kolkata 700087, West Bengal, India dist =>  0.29602379133090617  +  22.56004351018036  +  88.35196495056152
# item loop =>  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  ==  22.560426803438386  ==  88.35136049690179
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.2893734449398601
# Total dist of  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India  is =>  0.2893734449398601
# Minimum =>  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India dist =>  0.2893734449398601  +  22.560426803438386  +  88.35136049690179
# $$$$Minimum =>  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India dist =>  0.2893734449398601  +  22.560426803438386  +  88.35136049690179
# item loop =>  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  ==  22.562030018585972  ==  88.35358500480652
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.5705118503116864
# Total dist of  Paris Bar & Restaurant
#  and Location : 4A, Hogg St, Kolkata 700069, West Bengal, India  is =>  0.5705118503116864
# $$$$Minimum =>  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India dist =>  0.2893734449398601  +  22.560426803438386  +  88.35136049690179
# item loop =>  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  ==  22.575226445065066  ==  88.3516001701355
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  1.8996086923084774
# Total dist of  Zero Miles Bar & Restaurant
#  and Location : 11, Brabourne Rd, Kolkata 700001, West Bengal, India  is =>  1.8996086923084774
# $$$$Minimum =>  New Empire Cinema Bar
#  and Location : New Empire Cinema, Kolkata 700 013, West Bengal, India dist =>  0.2893734449398601  +  22.560426803438386  +  88.35136049690179
# item loop =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  ==  22.55909235388091  ==  88.3507204055786
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.13079834684673425
# Total dist of  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India  is =>  0.13079834684673425
# Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  ==  22.552894815519846  ==  88.35281252861023
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.6657363357416587
# Total dist of  Barista
#  and Location : 57, Park St, Kolkata 700016, West Bengal, India  is =>  0.6657363357416587
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  ==  22.55841  ==  88.35202
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.22263588520130667
# Total dist of  Sunset Bar
#  and Location : Kolkata 700016, West Bengal, India  is =>  0.22263588520130667
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  ==  22.5570331  ==  88.3480174
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.2311754517283433
# Total dist of  Pepsi Snacks Bar
#  and Location : Bertram St, Taltala, Kolkata, West Bengal, Kolkata, West Bengal, India  is =>  0.2311754517283433
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  ==  22.55509898976233  ==  88.35039785030294
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.35190490638373273
# Total dist of  Kusum Snack Bar
#  and Location : Park St, Kolkata 700016, West Bengal, India  is =>  0.35190490638373273
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  ==  22.553809399418334  ==  88.3516770971553
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.5252226220485868
# Total dist of  Cha Bar
#  and Location : Oxford Book Stall, Kolkata 700016, West Bengal, India  is =>  0.5252226220485868
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Nagraj Bar
#  and Location : Bengal Club, India  ==  22.55336490115175  ==  88.35094793669646
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Nagraj Bar
#  and Location : Bengal Club, India  to  Sams Pub
#  and Location : India  is:=>  0.5518476490919924
# Total dist of  Nagraj Bar
#  and Location : Bengal Club, India  is =>  0.5518476490919924
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  ==  22.5816  ==  88.3416
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  2.73510329954237
# Total dist of  IRCTC Snacks Bar
#  and Location : Howrah Station, Hāora 711101, West Bengal, India  is =>  2.73510329954237
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  ==  22.551066711460887  ==  88.35397124290466
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.9010699394608097
# Total dist of  Bodega Cantina Y Bar
#  and Location : 24, Park St, Kolkata 700020, West Bengal, India  is =>  0.9010699394608097
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  ==  22.552565  ==  88.350703
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  0.6353294962164175
# Total dist of  Sports Bar
#  and Location : Bengal Club (Russel Street), Kolkata, West Bengal, India  is =>  0.6353294962164175
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  M Bar and Kitchen
#  and Location : India  ==  22.551271548058658  ==  88.35345168984142
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  M Bar and Kitchen
#  and Location : India  to  Sams Pub
#  and Location : India  is:=>  0.856716059387882
# Total dist of  M Bar and Kitchen
#  and Location : India  is =>  0.856716059387882
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  ==  22.570218490509358  ==  88.35000157356262
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  1.3342433626092465
# Total dist of  Titos
#  and Location : 12, Old Court House St, Kolkata 700001, West Bengal, India  is =>  1.3342433626092465
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  ==  22.57159442335056  ==  88.40526765640105
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  5.882091691917858
# Total dist of  The Bar
#  and Location : Hyatt Regency Kolkata, Kolkata 700098, West Bengal, India  is =>  5.882091691917858
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  ==  22.56661118962308  ==  88.35588891639183
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  1.1196404699301639
# Total dist of  Chandni Chowk Market
#  and Location : Jawaharlal Nehru Rd, Kolkata 700072, West Bengal, India  is =>  1.1196404699301639
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# item loop =>  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  ==  22.5761994  ==  88.3488699
# class2 =>  bar
#
#
# min_dist_vert =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]]]
# 2nd check =>  Sams Pub
#  and Location : India  ==  22.558223809925604  ==  88.34986198355678[+] dist from  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  to  Sams Pub
#  and Location : India  is:=>  2.002016847225537
# Total dist of  Bardia Trading Company
#  and Location : 11 Clive Row, Kolkata 700001, West Bengal, India  is =>  2.002016847225537
# $$$$Minimum =>  1658 Bar & Kitchen
#  and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India dist =>  0.13079834684673425  +  22.55909235388091  +  88.3507204055786
# MIN DIST VERT LIST =>  [['Sams Pub\n and Location : India', [22.558223809925604, 88.34986198355678]], ['1658 Bar & Kitchen\n and Location : 26, Chowringhee Rd, Kolkata 700087, West Bengal, India', [22.55909235388091, 88.3507204055786]]]
# [22.558223809925604, 88.34986198355678] , [22.558223809925604, 88.34986198355678]
# [22.558223809925604, 88.34986198355678] , [22.55909235388091, 88.3507204055786]
# [22.55909235388091, 88.3507204055786] , [22.558223809925604, 88.34986198355678]
# [22.55909235388091, 88.3507204055786] , [22.55909235388091, 88.3507204055786]

# %%
MAP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
MAP.save("{}_{}.html".format(address,No_Q))
