# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from IPython.display import Image 
from IPython.core.display import HTML 
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
address = 'Kolkata'

geolocator = Nominatim(timeout=10)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 22.5677459 88.3476023

# %%
search_query = 'Ice cream'
radius = 5000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
#url
results = requests.get(url).json()
# Out:
# Ice cream .... OK!

# %%
import pprint
import json
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# {
#     "meta": {
#         "code": 200,
#         "requestId": "5d060ea4342adf0030313f4e"
#     },
#     "response": {
#         "venues": [
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5a251d6151950e28670124d5",
#                 "location": {
#                     "address": "77/1A, Park St",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 2002,
#                     "formattedAddress": [
#                         "77/1A, Park St",
#                         "Kolkata 700016",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.55040148166979,
#                             "lng": 88.352759378656
#                         }
#                     ],
#                     "lat": 22.55040148166979,
#                     "lng": 88.352759378656,
#                     "postalCode": "700016",
#                     "state": "West Bengal"
#                 },
#                 "name": "Naturals Ice Cream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "563a2d16cd103f210627133e",
#                 "location": {
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 1646,
#                     "formattedAddress": [
#                         "Kolkata",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.553568,
#                             "lng": 88.352151
#                         }
#                     ],
#                     "lat": 22.553568,
#                     "lng": 88.352151,
#                     "state": "West Bengal"
#                 },
#                 "name": "Metro Ice Cream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5bc0aa3d2b274a002cacebef",
#                 "location": {
#                     "address": "Pandit Madan Mohan Malviya Sarani",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3919,
#                     "formattedAddress": [
#                         "Pandit Madan Mohan Malviya Sarani",
#                         "Kolkata 700020",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.532596052586726,
#                             "lng": 88.34977626800537
#                         }
#                     ],
#                     "lat": 22.532596052586726,
#                     "lng": 88.34977626800537,
#                     "postalCode": "700020",
#                     "state": "West Bengal"
#                 },
#                 "name": "Arihant's Natural Ice Cream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "59d6377bb23dfa72cc1059a9",
#                 "location": {
#                     "address": "18A, Ram Mohan Dutta Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3742,
#                     "formattedAddress": [
#                         "18A, Ram Mohan Dutta Rd",
#                         "Kolkata 700020",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.534270801106587,
#                             "lng": 88.35102081298828
#                         }
#                     ],
#                     "lat": 22.534270801106587,
#                     "lng": 88.35102081298828,
#                     "postalCode": "700020",
#                     "state": "West Bengal"
#                 },
#                 "name": "Thanco's Natural Ice Cream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5bf423205c6838002cd59d6d",
#                 "location": {
#                     "address": "2, Broad St",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 4804,
#                     "formattedAddress": [
#                         "2, Broad St",
#                         "Kolkata 700019",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.52824557543919,
#                             "lng": 88.36643815040588
#                         }
#                     ],
#                     "lat": 22.52824557543919,
#                     "lng": 88.36643815040588,
#                     "postalCode": "700019",
#                     "state": "West Bengal"
#                 },
#                 "name": "Giani's Ice Cream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4efd6fb0d3e364d5fa15d32d",
#                 "location": {
#                     "address": "3-A, Humayun Pl",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 907,
#                     "formattedAddress": [
#                         "3-A, Humayun Pl",
#                         "Kolkata 700087",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.560657795137473,
#                             "lng": 88.35195422172546
#                         }
#                     ],
#                     "lat": 22.560657795137473,
#                     "lng": 88.35195422172546,
#                     "postalCode": "700087",
#                     "state": "West Bengal"
#                 },
#                 "name": "The Cream & Fudge Factory",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d110941735",
#                         "name": "Italian Restaurant",
#                         "pluralName": "Italian Restaurants",
#                         "primary": true,
#                         "shortName": "Italian"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4bfe9972b68d0f477e6dea57",
#                 "location": {
#                     "address": "41, Jawaharlal Nehru Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 2050,
#                     "formattedAddress": [
#                         "41, Jawaharlal Nehru Rd",
#                         "Kolkata 700071",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.54940945481822,
#                             "lng": 88.34947060482715
#                         }
#                     ],
#                     "lat": 22.54940945481822,
#                     "lng": 88.34947060482715,
#                     "postalCode": "700071",
#                     "state": "West Bengal"
#                 },
#                 "name": "Fire N Ice",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/vegetarian_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1d3941735",
#                         "name": "Vegetarian / Vegan Restaurant",
#                         "pluralName": "Vegetarian / Vegan Restaurants",
#                         "primary": true,
#                         "shortName": "Vegetarian / Vegan"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4e53c6616284ca6a2f74bc2c",
#                 "location": {
#                     "address": "1, Allenby Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3424,
#                     "formattedAddress": [
#                         "1, Allenby Rd",
#                         "Kolkata 700020",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.53719413002914,
#                             "lng": 88.35153579711914
#                         }
#                     ],
#                     "lat": 22.53719413002914,
#                     "lng": 88.35153579711914,
#                     "postalCode": "700020",
#                     "state": "West Bengal"
#                 },
#                 "name": "Cream Centre",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5bb6d1a6a35dce002cbd501f",
#                 "location": {
#                     "address": "52A, Sarat Bose Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 4079,
#                     "formattedAddress": [
#                         "52A, Sarat Bose Rd",
#                         "Kolkata 700025",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.531466329096567,
#                             "lng": 88.35317730903624
#                         }
#                     ],
#                     "lat": 22.531466329096567,
#                     "lng": 88.35317730903624,
#                     "postalCode": "700025",
#                     "state": "West Bengal"
#                 },
#                 "name": "Ice-O-Metry",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "53c2a1a2498edeb545c9a772",
#                 "location": {
#                     "cc": "IN",
#                     "country": "India",
#                     "distance": 1759,
#                     "formattedAddress": [
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.552854537963867,
#                             "lng": 88.35334014892578
#                         }
#                     ],
#                     "lat": 22.552854537963867,
#                     "lng": 88.35334014892578
#                 },
#                 "name": "Cream Fudge",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1f7941735",
#                         "name": "Flea Market",
#                         "pluralName": "Flea Markets",
#                         "primary": true,
#                         "shortName": "Flea Market"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4cd943826e8b5941928f64d2",
#                 "location": {
#                     "address": "78, Syed Amir Ali Ave",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 4911,
#                     "formattedAddress": [
#                         "78, Syed Amir Ali Ave",
#                         "Kolkata 700019",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.52705001628729,
#                             "lng": 88.36606309048823
#                         }
#                     ],
#                     "lat": 22.52705001628729,
#                     "lng": 88.36606309048823,
#                     "postalCode": "700019",
#                     "state": "West Bengal"
#                 },
#                 "name": "Ice Skating Rink",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "55287d2d498e003e2d5d71e5",
#                 "location": {
#                     "address": "28, Sarat Bose Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3835,
#                     "formattedAddress": [
#                         "28, Sarat Bose Rd",
#                         "Kolkata 700020",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.533725766835417,
#                             "lng": 88.35348844528198
#                         }
#                     ],
#                     "lat": 22.533725766835417,
#                     "lng": 88.35348844528198,
#                     "postalCode": "700020",
#                     "state": "West Bengal"
#                 },
#                 "name": "Pabrai's Fresh & Naturelle Icecream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/juicebar_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d112941735",
#                         "name": "Juice Bar",
#                         "pluralName": "Juice Bars",
#                         "primary": true,
#                         "shortName": "Juice Bar"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5c1f80944c954c002c4253c1",
#                 "location": {
#                     "address": "10A, S. P. Mukherjee Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 4396,
#                     "formattedAddress": [
#                         "10A, S. P. Mukherjee Rd",
#                         "Kolkata 700025",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.528301,
#                             "lng": 88.34547
#                         }
#                     ],
#                     "lat": 22.528301,
#                     "lng": 88.34547,
#                     "postalCode": "700025",
#                     "state": "West Bengal"
#                 },
#                 "name": "Ice on Fire",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d16a941735",
#                         "name": "Bakery",
#                         "pluralName": "Bakeries",
#                         "primary": true,
#                         "shortName": "Bakery"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4b81757cf964a52075a730e3",
#                 "location": {
#                     "address": "1, Ballygunge Park Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 4099,
#                     "formattedAddress": [
#                         "1, Ballygunge Park Rd",
#                         "Kolkata 700019",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.53454891550832,
#                             "lng": 88.36485351370527
#                         }
#                     ],
#                     "lat": 22.53454891550832,
#                     "lng": 88.36485351370527,
#                     "postalCode": "700019",
#                     "state": "West Bengal"
#                 },
#                 "name": "The Cream & Fudge Factory",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1c9941735",
#                         "name": "Ice Cream Shop",
#                         "pluralName": "Ice Cream Shops",
#                         "primary": true,
#                         "shortName": "Ice Cream"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4f638008e4b0777dfb77264d",
#                 "location": {
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 1802,
#                     "formattedAddress": [
#                         "Kolkata",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.551820510357864,
#                             "lng": 88.35076299463768
#                         }
#                     ],
#                     "lat": 22.551820510357864,
#                     "lng": 88.35076299463768,
#                     "state": "West Bengal"
#                 },
#                 "name": "Pabrai's Fresh & Naturelle Icecream",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1d0941735",
#                         "name": "Dessert Shop",
#                         "pluralName": "Dessert Shops",
#                         "primary": true,
#                         "shortName": "Desserts"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "4e47ae55887781a619bb47ef",
#                 "location": {
#                     "address": "The Enclave",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 5320,
#                     "formattedAddress": [
#                         "The Enclave",
#                         "Kolkata 700027",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.52226963972952,
#                             "lng": 88.33168745040894
#                         }
#                     ],
#                     "lat": 22.52226963972952,
#                     "lng": 88.33168745040894,
#                     "postalCode": "700027",
#                     "state": "West Bengal"
#                 },
#                 "name": "The Cream & Fudge Factory",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d16e941735",
#                         "name": "Fast Food Restaurant",
#                         "pluralName": "Fast Food Restaurants",
#                         "primary": true,
#                         "shortName": "Fast Food"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "522b191711d2718de5d46e15",
#                 "location": {
#                     "address": "46/2/1B, Gariahat Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 5991,
#                     "formattedAddress": [
#                         "46/2/1B, Gariahat Rd",
#                         "Kolkata 700029",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.516689884344576,
#                             "lng": 88.36605191230774
#                         }
#                     ],
#                     "lat": 22.516689884344576,
#                     "lng": 88.36605191230774,
#                     "postalCode": "700029",
#                     "state": "West Bengal"
#                 },
#                 "name": "Iceberg",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1d0941735",
#                         "name": "Dessert Shop",
#                         "pluralName": "Dessert Shops",
#                         "primary": true,
#                         "shortName": "Desserts"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "521e0bd37e4899d0d4898437",
#                 "location": {
#                     "address": "Forum Mall",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3263,
#                     "formattedAddress": [
#                         "Forum Mall",
#                         "Kolkata 700020",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.53860126968133,
#                             "lng": 88.35099935531616
#                         }
#                     ],
#                     "lat": 22.53860126968133,
#                     "lng": 88.35099935531616,
#                     "postalCode": "700020",
#                     "state": "West Bengal"
#                 },
#                 "name": "The Cream & Fudge Factory",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1d0941735",
#                         "name": "Dessert Shop",
#                         "pluralName": "Dessert Shops",
#                         "primary": true,
#                         "shortName": "Desserts"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "58f22225c8772e1a0591206d",
#                 "location": {
#                     "address": "Food Court, Quest Mall",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3683,
#                     "formattedAddress": [
#                         "Food Court, Quest Mall",
#                         "Kolkata 700017",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.539080835403254,
#                             "lng": 88.3654989748568
#                         }
#                     ],
#                     "lat": 22.539080835403254,
#                     "lng": 88.3654989748568,
#                     "postalCode": "700017",
#                     "state": "West Bengal"
#                 },
#                 "name": "Cream & Fudge",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/asian_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d145941735",
#                         "name": "Chinese Restaurant",
#                         "pluralName": "Chinese Restaurants",
#                         "primary": true,
#                         "shortName": "Chinese"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "51fdb256498ebdc46a91b5d9",
#                 "location": {
#                     "address": "54, Harish Mukherjee Rd",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 3792,
#                     "formattedAddress": [
#                         "54, Harish Mukherjee Rd",
#                         "Kolkata 700025",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.533874412759076,
#                             "lng": 88.34361791610718
#                         }
#                     ],
#                     "lat": 22.533874412759076,
#                     "lng": 88.34361791610718,
#                     "postalCode": "700025",
#                     "state": "West Bengal"
#                 },
#                 "name": "Little China",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d1d0941735",
#                         "name": "Dessert Shop",
#                         "pluralName": "Dessert Shops",
#                         "primary": true,
#                         "shortName": "Desserts"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "5ad6cc6fdb3aef7bea1d7a3b",
#                 "location": {
#                     "address": "Forum Rangoli",
#                     "cc": "IN",
#                     "city": "H\u0101ora",
#                     "country": "India",
#                     "distance": 6287,
#                     "formattedAddress": [
#                         "Forum Rangoli",
#                         "H\u0101ora 711202",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.62394617082759,
#                             "lng": 88.35374593734741
#                         }
#                     ],
#                     "lat": 22.62394617082759,
#                     "lng": 88.35374593734741,
#                     "postalCode": "711202",
#                     "state": "West Bengal"
#                 },
#                 "name": "Cream & Fudge",
#                 "referralId": "v-1560678052"
#             },
#             {
#                 "categories": [
#                     {
#                         "icon": {
#                             "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_",
#                             "suffix": ".png"
#                         },
#                         "id": "4bf58dd8d48988d118951735",
#                         "name": "Grocery Store",
#                         "pluralName": "Grocery Stores",
#                         "primary": true,
#                         "shortName": "Grocery Store"
#                     }
#                 ],
#                 "hasPerk": false,
#                 "id": "51028c1ce4b04647d18cb3a9",
#                 "location": {
#                     "address": "104, Rash Behari Ave",
#                     "cc": "IN",
#                     "city": "Kolkata",
#                     "country": "India",
#                     "distance": 5686,
#                     "formattedAddress": [
#                         "104, Rash Behari Ave",
#                         "Kolkata 700029",
#                         "West Bengal",
#                         "India"
#                     ],
#                     "labeledLatLngs": [
#                         {
#                             "label": "display",
#                             "lat": 22.51667997338858,
#                             "lng": 88.34912180900574
#                         }
#                     ],
#                     "lat": 22.51667997338858,
#                     "lng": 88.34912180900574,
#                     "postalCode": "700029",
#                     "state": "West Bengal"
#                 },
#                 "name": "Calcutta Creamery Stores",
#                 "referralId": "v-1560678052"
#             }
#         ]
#     }
# }

# %%
item = results['response']['venues']
print(json.dumps(item, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5a251d6151950e28670124d5",
#         "location": {
#             "address": "77/1A, Park St",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 2002,
#             "formattedAddress": [
#                 "77/1A, Park St",
#                 "Kolkata 700016",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.55040148166979,
#                     "lng": 88.352759378656
#                 }
#             ],
#             "lat": 22.55040148166979,
#             "lng": 88.352759378656,
#             "postalCode": "700016",
#             "state": "West Bengal"
#         },
#         "name": "Naturals Ice Cream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "563a2d16cd103f210627133e",
#         "location": {
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 1646,
#             "formattedAddress": [
#                 "Kolkata",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.553568,
#                     "lng": 88.352151
#                 }
#             ],
#             "lat": 22.553568,
#             "lng": 88.352151,
#             "state": "West Bengal"
#         },
#         "name": "Metro Ice Cream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5bc0aa3d2b274a002cacebef",
#         "location": {
#             "address": "Pandit Madan Mohan Malviya Sarani",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3919,
#             "formattedAddress": [
#                 "Pandit Madan Mohan Malviya Sarani",
#                 "Kolkata 700020",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.532596052586726,
#                     "lng": 88.34977626800537
#                 }
#             ],
#             "lat": 22.532596052586726,
#             "lng": 88.34977626800537,
#             "postalCode": "700020",
#             "state": "West Bengal"
#         },
#         "name": "Arihant's Natural Ice Cream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "59d6377bb23dfa72cc1059a9",
#         "location": {
#             "address": "18A, Ram Mohan Dutta Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3742,
#             "formattedAddress": [
#                 "18A, Ram Mohan Dutta Rd",
#                 "Kolkata 700020",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.534270801106587,
#                     "lng": 88.35102081298828
#                 }
#             ],
#             "lat": 22.534270801106587,
#             "lng": 88.35102081298828,
#             "postalCode": "700020",
#             "state": "West Bengal"
#         },
#         "name": "Thanco's Natural Ice Cream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5bf423205c6838002cd59d6d",
#         "location": {
#             "address": "2, Broad St",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 4804,
#             "formattedAddress": [
#                 "2, Broad St",
#                 "Kolkata 700019",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.52824557543919,
#                     "lng": 88.36643815040588
#                 }
#             ],
#             "lat": 22.52824557543919,
#             "lng": 88.36643815040588,
#             "postalCode": "700019",
#             "state": "West Bengal"
#         },
#         "name": "Giani's Ice Cream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4efd6fb0d3e364d5fa15d32d",
#         "location": {
#             "address": "3-A, Humayun Pl",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 907,
#             "formattedAddress": [
#                 "3-A, Humayun Pl",
#                 "Kolkata 700087",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.560657795137473,
#                     "lng": 88.35195422172546
#                 }
#             ],
#             "lat": 22.560657795137473,
#             "lng": 88.35195422172546,
#             "postalCode": "700087",
#             "state": "West Bengal"
#         },
#         "name": "The Cream & Fudge Factory",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d110941735",
#                 "name": "Italian Restaurant",
#                 "pluralName": "Italian Restaurants",
#                 "primary": true,
#                 "shortName": "Italian"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4bfe9972b68d0f477e6dea57",
#         "location": {
#             "address": "41, Jawaharlal Nehru Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 2050,
#             "formattedAddress": [
#                 "41, Jawaharlal Nehru Rd",
#                 "Kolkata 700071",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.54940945481822,
#                     "lng": 88.34947060482715
#                 }
#             ],
#             "lat": 22.54940945481822,
#             "lng": 88.34947060482715,
#             "postalCode": "700071",
#             "state": "West Bengal"
#         },
#         "name": "Fire N Ice",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/vegetarian_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1d3941735",
#                 "name": "Vegetarian / Vegan Restaurant",
#                 "pluralName": "Vegetarian / Vegan Restaurants",
#                 "primary": true,
#                 "shortName": "Vegetarian / Vegan"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4e53c6616284ca6a2f74bc2c",
#         "location": {
#             "address": "1, Allenby Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3424,
#             "formattedAddress": [
#                 "1, Allenby Rd",
#                 "Kolkata 700020",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.53719413002914,
#                     "lng": 88.35153579711914
#                 }
#             ],
#             "lat": 22.53719413002914,
#             "lng": 88.35153579711914,
#             "postalCode": "700020",
#             "state": "West Bengal"
#         },
#         "name": "Cream Centre",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5bb6d1a6a35dce002cbd501f",
#         "location": {
#             "address": "52A, Sarat Bose Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 4079,
#             "formattedAddress": [
#                 "52A, Sarat Bose Rd",
#                 "Kolkata 700025",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.531466329096567,
#                     "lng": 88.35317730903624
#                 }
#             ],
#             "lat": 22.531466329096567,
#             "lng": 88.35317730903624,
#             "postalCode": "700025",
#             "state": "West Bengal"
#         },
#         "name": "Ice-O-Metry",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "53c2a1a2498edeb545c9a772",
#         "location": {
#             "cc": "IN",
#             "country": "India",
#             "distance": 1759,
#             "formattedAddress": [
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.552854537963867,
#                     "lng": 88.35334014892578
#                 }
#             ],
#             "lat": 22.552854537963867,
#             "lng": 88.35334014892578
#         },
#         "name": "Cream Fudge",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1f7941735",
#                 "name": "Flea Market",
#                 "pluralName": "Flea Markets",
#                 "primary": true,
#                 "shortName": "Flea Market"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4cd943826e8b5941928f64d2",
#         "location": {
#             "address": "78, Syed Amir Ali Ave",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 4911,
#             "formattedAddress": [
#                 "78, Syed Amir Ali Ave",
#                 "Kolkata 700019",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.52705001628729,
#                     "lng": 88.36606309048823
#                 }
#             ],
#             "lat": 22.52705001628729,
#             "lng": 88.36606309048823,
#             "postalCode": "700019",
#             "state": "West Bengal"
#         },
#         "name": "Ice Skating Rink",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "55287d2d498e003e2d5d71e5",
#         "location": {
#             "address": "28, Sarat Bose Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3835,
#             "formattedAddress": [
#                 "28, Sarat Bose Rd",
#                 "Kolkata 700020",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.533725766835417,
#                     "lng": 88.35348844528198
#                 }
#             ],
#             "lat": 22.533725766835417,
#             "lng": 88.35348844528198,
#             "postalCode": "700020",
#             "state": "West Bengal"
#         },
#         "name": "Pabrai's Fresh & Naturelle Icecream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/juicebar_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d112941735",
#                 "name": "Juice Bar",
#                 "pluralName": "Juice Bars",
#                 "primary": true,
#                 "shortName": "Juice Bar"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5c1f80944c954c002c4253c1",
#         "location": {
#             "address": "10A, S. P. Mukherjee Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 4396,
#             "formattedAddress": [
#                 "10A, S. P. Mukherjee Rd",
#                 "Kolkata 700025",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.528301,
#                     "lng": 88.34547
#                 }
#             ],
#             "lat": 22.528301,
#             "lng": 88.34547,
#             "postalCode": "700025",
#             "state": "West Bengal"
#         },
#         "name": "Ice on Fire",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d16a941735",
#                 "name": "Bakery",
#                 "pluralName": "Bakeries",
#                 "primary": true,
#                 "shortName": "Bakery"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4b81757cf964a52075a730e3",
#         "location": {
#             "address": "1, Ballygunge Park Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 4099,
#             "formattedAddress": [
#                 "1, Ballygunge Park Rd",
#                 "Kolkata 700019",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.53454891550832,
#                     "lng": 88.36485351370527
#                 }
#             ],
#             "lat": 22.53454891550832,
#             "lng": 88.36485351370527,
#             "postalCode": "700019",
#             "state": "West Bengal"
#         },
#         "name": "The Cream & Fudge Factory",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1c9941735",
#                 "name": "Ice Cream Shop",
#                 "pluralName": "Ice Cream Shops",
#                 "primary": true,
#                 "shortName": "Ice Cream"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4f638008e4b0777dfb77264d",
#         "location": {
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 1802,
#             "formattedAddress": [
#                 "Kolkata",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.551820510357864,
#                     "lng": 88.35076299463768
#                 }
#             ],
#             "lat": 22.551820510357864,
#             "lng": 88.35076299463768,
#             "state": "West Bengal"
#         },
#         "name": "Pabrai's Fresh & Naturelle Icecream",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1d0941735",
#                 "name": "Dessert Shop",
#                 "pluralName": "Dessert Shops",
#                 "primary": true,
#                 "shortName": "Desserts"
#             }
#         ],
#         "hasPerk": false,
#         "id": "4e47ae55887781a619bb47ef",
#         "location": {
#             "address": "The Enclave",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 5320,
#             "formattedAddress": [
#                 "The Enclave",
#                 "Kolkata 700027",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.52226963972952,
#                     "lng": 88.33168745040894
#                 }
#             ],
#             "lat": 22.52226963972952,
#             "lng": 88.33168745040894,
#             "postalCode": "700027",
#             "state": "West Bengal"
#         },
#         "name": "The Cream & Fudge Factory",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d16e941735",
#                 "name": "Fast Food Restaurant",
#                 "pluralName": "Fast Food Restaurants",
#                 "primary": true,
#                 "shortName": "Fast Food"
#             }
#         ],
#         "hasPerk": false,
#         "id": "522b191711d2718de5d46e15",
#         "location": {
#             "address": "46/2/1B, Gariahat Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 5991,
#             "formattedAddress": [
#                 "46/2/1B, Gariahat Rd",
#                 "Kolkata 700029",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.516689884344576,
#                     "lng": 88.36605191230774
#                 }
#             ],
#             "lat": 22.516689884344576,
#             "lng": 88.36605191230774,
#             "postalCode": "700029",
#             "state": "West Bengal"
#         },
#         "name": "Iceberg",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1d0941735",
#                 "name": "Dessert Shop",
#                 "pluralName": "Dessert Shops",
#                 "primary": true,
#                 "shortName": "Desserts"
#             }
#         ],
#         "hasPerk": false,
#         "id": "521e0bd37e4899d0d4898437",
#         "location": {
#             "address": "Forum Mall",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3263,
#             "formattedAddress": [
#                 "Forum Mall",
#                 "Kolkata 700020",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.53860126968133,
#                     "lng": 88.35099935531616
#                 }
#             ],
#             "lat": 22.53860126968133,
#             "lng": 88.35099935531616,
#             "postalCode": "700020",
#             "state": "West Bengal"
#         },
#         "name": "The Cream & Fudge Factory",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1d0941735",
#                 "name": "Dessert Shop",
#                 "pluralName": "Dessert Shops",
#                 "primary": true,
#                 "shortName": "Desserts"
#             }
#         ],
#         "hasPerk": false,
#         "id": "58f22225c8772e1a0591206d",
#         "location": {
#             "address": "Food Court, Quest Mall",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3683,
#             "formattedAddress": [
#                 "Food Court, Quest Mall",
#                 "Kolkata 700017",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.539080835403254,
#                     "lng": 88.3654989748568
#                 }
#             ],
#             "lat": 22.539080835403254,
#             "lng": 88.3654989748568,
#             "postalCode": "700017",
#             "state": "West Bengal"
#         },
#         "name": "Cream & Fudge",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/asian_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d145941735",
#                 "name": "Chinese Restaurant",
#                 "pluralName": "Chinese Restaurants",
#                 "primary": true,
#                 "shortName": "Chinese"
#             }
#         ],
#         "hasPerk": false,
#         "id": "51fdb256498ebdc46a91b5d9",
#         "location": {
#             "address": "54, Harish Mukherjee Rd",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 3792,
#             "formattedAddress": [
#                 "54, Harish Mukherjee Rd",
#                 "Kolkata 700025",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.533874412759076,
#                     "lng": 88.34361791610718
#                 }
#             ],
#             "lat": 22.533874412759076,
#             "lng": 88.34361791610718,
#             "postalCode": "700025",
#             "state": "West Bengal"
#         },
#         "name": "Little China",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d1d0941735",
#                 "name": "Dessert Shop",
#                 "pluralName": "Dessert Shops",
#                 "primary": true,
#                 "shortName": "Desserts"
#             }
#         ],
#         "hasPerk": false,
#         "id": "5ad6cc6fdb3aef7bea1d7a3b",
#         "location": {
#             "address": "Forum Rangoli",
#             "cc": "IN",
#             "city": "H\u0101ora",
#             "country": "India",
#             "distance": 6287,
#             "formattedAddress": [
#                 "Forum Rangoli",
#                 "H\u0101ora 711202",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.62394617082759,
#                     "lng": 88.35374593734741
#                 }
#             ],
#             "lat": 22.62394617082759,
#             "lng": 88.35374593734741,
#             "postalCode": "711202",
#             "state": "West Bengal"
#         },
#         "name": "Cream & Fudge",
#         "referralId": "v-1560678052"
#     },
#     {
#         "categories": [
#             {
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_",
#                     "suffix": ".png"
#                 },
#                 "id": "4bf58dd8d48988d118951735",
#                 "name": "Grocery Store",
#                 "pluralName": "Grocery Stores",
#                 "primary": true,
#                 "shortName": "Grocery Store"
#             }
#         ],
#         "hasPerk": false,
#         "id": "51028c1ce4b04647d18cb3a9",
#         "location": {
#             "address": "104, Rash Behari Ave",
#             "cc": "IN",
#             "city": "Kolkata",
#             "country": "India",
#             "distance": 5686,
#             "formattedAddress": [
#                 "104, Rash Behari Ave",
#                 "Kolkata 700029",
#                 "West Bengal",
#                 "India"
#             ],
#             "labeledLatLngs": [
#                 {
#                     "label": "display",
#                     "lat": 22.51667997338858,
#                     "lng": 88.34912180900574
#                 }
#             ],
#             "lat": 22.51667997338858,
#             "lng": 88.34912180900574,
#             "postalCode": "700029",
#             "state": "West Bengal"
#         },
#         "name": "Calcutta Creamery Stores",
#         "referralId": "v-1560678052"
#     }
# ]

# %%
data_ice = []
for item_ in item:
    #print(json.dumps(item_, indent=4, sort_keys=True))
    name = item_["name"]
    cat = item_["categories"]
    loc = ', '.join(item_["location"]["formattedAddress"])
    lat_ = item_["location"]["lat"]
    lon_ = item_["location"]["lng"]
    #add = item_["location"]
    #print(name)
    #print(cat)
    #print(loc)
    #print(lat_,"   +   ",lon_)
    data_ice.append(('ice cream',"Name : {} and Location : {}".format(name,loc),lat_,lon_))
    
print(data_ice)
# Out:
# [('ice cream', 'Name : Naturals Ice Cream and Location : 77/1A, Park St, Kolkata 700016, West Bengal, India', 22.55040148166979, 88.352759378656), ('ice cream', 'Name : Metro Ice Cream and Location : Kolkata, West Bengal, India', 22.553568, 88.352151), ('ice cream', "Name : Arihant's Natural Ice Cream and Location : Pandit Madan Mohan Malviya Sarani, Kolkata 700020, West Bengal, India", 22.532596052586726, 88.34977626800537), ('ice cream', "Name : Thanco's Natural Ice Cream and Location : 18A, Ram Mohan Dutta Rd, Kolkata 700020, West Bengal, India", 22.534270801106587, 88.35102081298828), ('ice cream', "Name : Giani's Ice Cream and Location : 2, Broad St, Kolkata 700019, West Bengal, India", 22.52824557543919, 88.36643815040588), ('ice cream', 'Name : The Cream & Fudge Factory and Location : 3-A, Humayun Pl, Kolkata 700087, West Bengal, India', 22.560657795137473, 88.35195422172546), ('ice cream', 'Name : Fire N Ice and Location : 41, Jawaharlal Nehru Rd, Kolkata 700071, West Bengal, India', 22.54940945481822, 88.34947060482715), ('ice cream', 'Name : Cream Centre and Location : 1, Allenby Rd, Kolkata 700020, West Bengal, India', 22.53719413002914, 88.35153579711914), ('ice cream', 'Name : Ice-O-Metry and Location : 52A, Sarat Bose Rd, Kolkata 700025, West Bengal, India', 22.531466329096567, 88.35317730903624), ('ice cream', 'Name : Cream Fudge and Location : India', 22.552854537963867, 88.35334014892578), ('ice cream', 'Name : Ice Skating Rink and Location : 78, Syed Amir Ali Ave, Kolkata 700019, West Bengal, India', 22.52705001628729, 88.36606309048823), ('ice cream', "Name : Pabrai's Fresh & Naturelle Icecream and Location : 28, Sarat Bose Rd, Kolkata 700020, West Bengal, India", 22.533725766835417, 88.35348844528198), ('ice cream', 'Name : Ice on Fire and Location : 10A, S. P. Mukherjee Rd, Kolkata 700025, West Bengal, India', 22.528301, 88.34547), ('ice cream', 'Name : The Cream & Fudge Factory and Location : 1, Ballygunge Park Rd, Kolkata 700019, West Bengal, India', 22.53454891550832, 88.36485351370527), ('ice cream', "Name : Pabrai's Fresh & Naturelle Icecream and Location : Kolkata, West Bengal, India", 22.551820510357864, 88.35076299463768), ('ice cream', 'Name : The Cream & Fudge Factory and Location : The Enclave, Kolkata 700027, West Bengal, India', 22.52226963972952, 88.33168745040894), ('ice cream', 'Name : Iceberg and Location : 46/2/1B, Gariahat Rd, Kolkata 700029, West Bengal, India', 22.516689884344576, 88.36605191230774), ('ice cream', 'Name : The Cream & Fudge Factory and Location : Forum Mall, Kolkata 700020, West Bengal, India', 22.53860126968133, 88.35099935531616), ('ice cream', 'Name : Cream & Fudge and Location : Food Court, Quest Mall, Kolkata 700017, West Bengal, India', 22.539080835403254, 88.3654989748568), ('ice cream', 'Name : Little China and Location : 54, Harish Mukherjee Rd, Kolkata 700025, West Bengal, India', 22.533874412759076, 88.34361791610718), ('ice cream', 'Name : Cream & Fudge and Location : Forum Rangoli, Hāora 711202, West Bengal, India', 22.62394617082759, 88.35374593734741), ('ice cream', 'Name : Calcutta Creamery Stores and Location : 104, Rash Behari Ave, Kolkata 700029, West Bengal, India', 22.51667997338858, 88.34912180900574)]
