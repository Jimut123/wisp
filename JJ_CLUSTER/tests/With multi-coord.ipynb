# %% [markdown]
# # Wisp Version 1 Original Algorithm (Jimut's Invention)

# %% [markdown]
# # Procedure :-> 1  Import necessary libraries

# %%
from tkinter import Tk, Label, Button, Entry, StringVar, DISABLED, NORMAL, END, W, E, N, S
# tranforming json file into a pandas dataframe library
from http.server import BaseHTTPRequestHandler, HTTPServer
from math import sin, cos, sqrt, atan2, radians
from pandas.io.json import json_normalize
from folium.plugins import MarkerCluster
from tempfile import NamedTemporaryFile
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from IPython.core.display import HTML 
from IPython.display import Image
from datetime import datetime
from tkinter import *
import tkinter as tk
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import subprocess
import webbrowser
import requests # library to handle requests
import argparse
import random # library for random number generation
import folium # plotting library
import json
import os

# %% [markdown]
# # Procedure :-> 2  Initialise Coordinates, data, type  along with the point to point actual distance calculator function

# %%
map_data = [("Meat","Khasi",22.569098,88.366418),
            ("Meat","Chasi",22.562298,88.376218),
            ("Tea","My Tea",22.582298,88.367218),
            ("Museum","museum1",22.570298,88.352218),
            ("Museum","museum2",22.492298,88.362218),
            ("Museum","museum3",22.592298,88.307218),
            ("Chinese Res","Indo China",22.542298,88.397218),
            ("Thai Res","My Thai",22.535298,88.397218),
            ("Thai Res","Thaism",22.535298,88.387218),
            ("Thai Res","Nilu Thai",22.538298,88.396218),
            ("Airport","NSCB",22.338298,88.333218),
            ("Fishery","DODO Fishery",22.738298,88.696218),
            ("Motel","Baloo's Dhaba",22.608298,88.437218)
           ]


# approximate radius of earth in km
R = 6373.0

def ret_dist(lat1,lon1,lat2,lon2):
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    #print("Result:", distance)
    #print("Should be:", 278.546, "km")
    return distance

# %% [markdown]
# # Procedure :-> 3 Show the coordinates

# %%
string_gen = "0123456789abcdef"
def get_random_col():
    # unnecessary stuffs to make the visualization cool
    ret_str = "#"
    for i in range(6):
        ret_str += random.choice(string_gen)
    return ret_str

latitude =  22.569098
longitude = 88.366418

MAP = folium.Map(location=[latitude, longitude],tiles="Stamen Toner", zoom_start=11)

name=map_data[0][0]

full_tree = []
data_cate = []
OVER_COL = str(get_random_col())
FILL_COL = str(get_random_col())
for item in map_data:
    lat = item[2]
    lng = item[3]
    print(item," => ")
    if(item[0]!=name):
        OVER_COL = str(get_random_col())
        FILL_COL = str(get_random_col())
        full_tree.append([name,data_cate])
        name=item[0]
        data_cate=[]
        print("got into first check")
    if(item[0]==name):
        data_cate.append([item[1],lat,lng])
        print("got into 2nd check")
    label = "cat : {}, Name : {}".format(item[0],item[1])
    folium.CircleMarker(
                        [lat, lng],
                        radius=5,
                        popup=label,
                        color=OVER_COL,
                        fill=True,
                        fill_color=FILL_COL,
                        fill_opacity=0.7).add_to(MAP)
full_tree.append((name,data_cate))
MAP
# Out:
# ('Meat', 'Khasi', 22.569098, 88.366418)  =>
# got into 2nd check
# ('Meat', 'Chasi', 22.562298, 88.376218)  =>
# got into 2nd check
# ('Tea', 'My Tea', 22.582298, 88.367218)  =>
# got into first check
# got into 2nd check
# ('Museum', 'museum1', 22.570298, 88.352218)  =>
# got into first check
# got into 2nd check
# ('Museum', 'museum2', 22.492298, 88.362218)  =>
# got into 2nd check
# ('Museum', 'museum3', 22.592298, 88.307218)  =>
# got into 2nd check
# ('Chinese Res', 'Indo China', 22.542298, 88.397218)  =>
# got into first check
# got into 2nd check
# ('Thai Res', 'My Thai', 22.535298, 88.397218)  =>
# got into first check
# got into 2nd check
# ('Thai Res', 'Thaism', 22.535298, 88.387218)  =>
# got into 2nd check
# ('Thai Res', 'Nilu Thai', 22.538298, 88.396218)  =>
# got into 2nd check
# ('Airport', 'NSCB', 22.338298, 88.333218)  =>
# got into first check
# got into 2nd check
# ('Fishery', 'DODO Fishery', 22.738298, 88.696218)  =>
# got into first check
# got into 2nd check
# ('Motel', "Baloo's Dhaba", 22.608298, 88.437218)  =>
# got into first check
# got into 2nd check
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Procedure :-> 4 Show the bare lines

# %%
import pandas as pd 

distance_api = []
# for i in map_data:
#     print(i[0],end=" ")
# print()
index_mat = []
for i in map_data:
    lis = []
    index_mat.append(str(i[0]+"_"+i[1]))
    for j in map_data:
        
        #print(i[2],i[3]," ",j[2],j[3],end="")
        #distance_api.append([[i[2],i[3]],[j[2],j[3]],[ret_dist(i[2],i[3],j[2],j[3])]])
        lis.append(ret_dist(i[2],i[3],j[2],j[3]))
        #distance_api[([i[2],i[3])][([j[2],j[3]])] = ret_dist(i[2],i[3],j[2],j[3])
        #distance_api[i[1]][j[1]] = ret_dist(i[2],i[3],j[2],j[3])
        p1=[i[2],i[3]]
        p2=[j[2],j[3]]
        #print(DataFrame(ret_dist(i[2],i[3],j[2],j[3]),end="  "))
        folium.PolyLine(locations=[p1, p2], color='blue',weight=0.5,opacity=1).add_to(MAP)
    distance_api.append(lis)
    #print()
print(distance_api)
MAP
# Out:
# [[0.0, 1.2590966992752348, 1.4705310693205238, 1.4645926186841736, 8.553342738827284, 6.6049750985927815, 4.346941214152579, 4.9137195915993095, 4.324312604507568, 4.594264024099124, 25.897708762440658, 38.73305823304252, 8.478092248138596], [1.2590966992752348, 0.0, 2.4090067298288873, 2.6208140300702207, 7.917837977506495, 7.832996883255212, 3.0987684226633543, 3.6977039776113134, 3.2087580769447075, 3.3685800872732967, 25.304567126575012, 38.239336837795115, 8.088595670525862], [1.4705310693205238, 2.4090067298288873, 0.0, 2.038383021097454, 10.023855401720926, 6.261466783978278, 5.412111874555188, 6.068445506471385, 5.616975270900324, 5.729375020785105, 27.364182838226505, 37.966803876543516, 7.748368652645731], [1.4645926186841736, 2.6208140300702207, 2.038383021097454, 0.0, 8.736547001090008, 5.2294714723344535, 5.57375481564185, 6.043501637693017, 5.29926277739444, 5.753046037645829, 25.87912979842834, 39.95055915851938, 9.69867252198896], [8.553342738827284, 7.917837977506495, 10.023855401720926, 8.736547001090008, 0.0, 12.475811865631549, 6.62293214017525, 5.984117655630972, 5.429069224067849, 6.195501038326321, 17.387011049142743, 43.87247613586244, 15.027862818141001], [6.6049750985927815, 7.832996883255212, 6.261466783978278, 5.2294714723344535, 12.475811865631549, 0.0, 10.78817358778862, 11.209625786239236, 10.378820049105906, 10.938256585830558, 28.37849745679055, 43.10307298355485, 13.467583844484045], [4.346941214152579, 3.0987684226633543, 5.412111874555188, 5.57375481564185, 6.62293214017525, 10.78817358778862, 0.0, 0.7786088326069296, 1.2890545514893508, 0.4566259768111724, 23.62558415830091, 37.64915684024951, 8.41253251587534], [4.9137195915993095, 3.6977039776113134, 6.068445506471385, 6.043501637693017, 5.984117655630972, 11.209625786239236, 0.7786088326069296, 0.0, 1.0273672344217466, 0.3491465125505892, 22.87885484354797, 38.10593292546749, 9.099977455838893], [4.324312604507568, 3.2087580769447075, 5.616975270900324, 5.29926277739444, 5.429069224067849, 10.378820049105906, 1.2890545514893508, 1.0273672344217466, 0.0, 0.9829911947108576, 22.604636140492765, 38.937653512062525, 9.60749256290888], [4.594264024099124, 3.3685800872732967, 5.729375020785105, 5.753046037645829, 6.195501038326321, 10.938256585830558, 0.4566259768111724, 0.3491465125505892, 0.9829911947108576, 0.0, 23.16967546653363, 37.99206019044623, 8.851896555319634], [25.897708762440658, 25.304567126575012, 27.364182838226505, 25.87912979842834, 17.387011049142743, 28.37849745679055, 23.62558415830091, 22.87885484354797, 22.604636140492765, 23.16967546653363, 0.0, 58.05396117896989, 31.877695905737227], [38.73305823304252, 38.239336837795115, 37.966803876543516, 39.95055915851938, 43.87247613586244, 43.10307298355485, 37.64915684024951, 38.10593292546749, 38.937653512062525, 37.99206019044623, 58.05396117896989, 0.0, 30.260497152616665], [8.478092248138596, 8.088595670525862, 7.748368652645731, 9.69867252198896, 15.027862818141001, 13.467583844484045, 8.41253251587534, 9.099977455838893, 9.60749256290888, 8.851896555319634, 31.877695905737227, 30.260497152616665, 0.0]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Procedure :-> 5 Show the distance matrix

# %%
df = pd.DataFrame(distance_api, columns = list(index_mat), index=list(index_mat))
df
# Out:
#                         Meat_Khasi  Meat_Chasi  Tea_My Tea  Museum_museum1  \
# Meat_Khasi                0.000000    1.259097    1.470531        1.464593
# Meat_Chasi                1.259097    0.000000    2.409007        2.620814
# Tea_My Tea                1.470531    2.409007    0.000000        2.038383
# Museum_museum1            1.464593    2.620814    2.038383        0.000000
# Museum_museum2            8.553343    7.917838   10.023855        8.736547
# Museum_museum3            6.604975    7.832997    6.261467        5.229471
# Chinese Res_Indo China    4.346941    3.098768    5.412112        5.573755
# Thai Res_My Thai          4.913720    3.697704    6.068446        6.043502
# Thai Res_Thaism           4.324313    3.208758    5.616975        5.299263
# Thai Res_Nilu Thai        4.594264    3.368580    5.729375        5.753046
# Airport_NSCB             25.897709   25.304567   27.364183       25.879130
# Fishery_DODO Fishery     38.733058   38.239337   37.966804       39.950559
# Motel_Baloo's Dhaba       8.478092    8.088596    7.748369        9.698673
#
#                         Museum_museum2  Museum_museum3  \
# Meat_Khasi                    8.553343        6.604975
# Meat_Chasi                    7.917838        7.832997
# Tea_My Tea                   10.023855        6.261467
# Museum_museum1                8.736547        5.229471
# Museum_museum2                0.000000       12.475812
# Museum_museum3               12.475812        0.000000
# Chinese Res_Indo China        6.622932       10.788174
# Thai Res_My Thai              5.984118       11.209626
# Thai Res_Thaism               5.429069       10.378820
# Thai Res_Nilu Thai            6.195501       10.938257
# Airport_NSCB                 17.387011       28.378497
# Fishery_DODO Fishery         43.872476       43.103073
# Motel_Baloo's Dhaba          15.027863       13.467584
#
#                         Chinese Res_Indo China  Thai Res_My Thai  \
# Meat_Khasi                            4.346941          4.913720
# Meat_Chasi                            3.098768          3.697704
# Tea_My Tea                            5.412112          6.068446
# Museum_museum1                        5.573755          6.043502
# Museum_museum2                        6.622932          5.984118
# Museum_museum3                       10.788174         11.209626
# Chinese Res_Indo China                0.000000          0.778609
# Thai Res_My Thai                      0.778609          0.000000
# Thai Res_Thaism                       1.289055          1.027367
# Thai Res_Nilu Thai                    0.456626          0.349147
# Airport_NSCB                         23.625584         22.878855
# Fishery_DODO Fishery                 37.649157         38.105933
# Motel_Baloo's Dhaba                   8.412533          9.099977
#
#                         Thai Res_Thaism  Thai Res_Nilu Thai  Airport_NSCB  \
# Meat_Khasi                     4.324313            4.594264     25.897709
# Meat_Chasi                     3.208758            3.368580     25.304567
# Tea_My Tea                     5.616975            5.729375     27.364183
# Museum_museum1                 5.299263            5.753046     25.879130
# Museum_museum2                 5.429069            6.195501     17.387011
# Museum_museum3                10.378820           10.938257     28.378497
# Chinese Res_Indo China         1.289055            0.456626     23.625584
# Thai Res_My Thai               1.027367            0.349147     22.878855
# Thai Res_Thaism                0.000000            0.982991     22.604636
# Thai Res_Nilu Thai             0.982991            0.000000     23.169675
# Airport_NSCB                  22.604636           23.169675      0.000000
# Fishery_DODO Fishery          38.937654           37.992060     58.053961
# Motel_Baloo's Dhaba            9.607493            8.851897     31.877696
#
#                         Fishery_DODO Fishery  Motel_Baloo's Dhaba
# Meat_Khasi                         38.733058             8.478092
# Meat_Chasi                         38.239337             8.088596
# Tea_My Tea                         37.966804             7.748369
# Museum_museum1                     39.950559             9.698673
# Museum_museum2                     43.872476            15.027863
# Museum_museum3                     43.103073            13.467584
# Chinese Res_Indo China             37.649157             8.412533
# Thai Res_My Thai                   38.105933             9.099977
# Thai Res_Thaism                    38.937654             9.607493
# Thai Res_Nilu Thai                 37.992060             8.851897
# Airport_NSCB                       58.053961            31.877696
# Fishery_DODO Fishery                0.000000            30.260497
# Motel_Baloo's Dhaba                30.260497             0.000000

# %% [markdown]
# # Procedure :-> 6 Show the different points

# %%
for i in map_data:
    print(i)
# Out:
# ('Meat', 'Khasi', 22.569098, 88.366418)
# ('Meat', 'Chasi', 22.562298, 88.376218)
# ('Tea', 'My Tea', 22.582298, 88.367218)
# ('Museum', 'museum1', 22.570298, 88.352218)
# ('Museum', 'museum2', 22.492298, 88.362218)
# ('Museum', 'museum3', 22.592298, 88.307218)
# ('Chinese Res', 'Indo China', 22.542298, 88.397218)
# ('Thai Res', 'My Thai', 22.535298, 88.397218)
# ('Thai Res', 'Thaism', 22.535298, 88.387218)
# ('Thai Res', 'Nilu Thai', 22.538298, 88.396218)
# ('Airport', 'NSCB', 22.338298, 88.333218)
# ('Fishery', 'DODO Fishery', 22.738298, 88.696218)
# ('Motel', "Baloo's Dhaba", 22.608298, 88.437218)

# %% [markdown]
# # Procedure :-> 7 Show the tree with type clustered to Point coordinates

# %%
full_tree
# Out:
# [['Meat', [['Khasi', 22.569098, 88.366418], ['Chasi', 22.562298, 88.376218]]],
#  ['Tea', [['My Tea', 22.582298, 88.367218]]],
#  ['Museum',
#   [['museum1', 22.570298, 88.352218],
#    ['museum2', 22.492298, 88.362218],
#    ['museum3', 22.592298, 88.307218]]],
#  ['Chinese Res', [['Indo China', 22.542298, 88.397218]]],
#  ['Thai Res',
#   [['My Thai', 22.535298, 88.397218],
#    ['Thaism', 22.535298, 88.387218],
#    ['Nilu Thai', 22.538298, 88.396218]]],
#  ['Airport', [['NSCB', 22.338298, 88.333218]]],
#  ['Fishery', [['DODO Fishery', 22.738298, 88.696218]]],
#  ('Motel', [["Baloo's Dhaba", 22.608298, 88.437218]])]

# %% [markdown]
# # Procedure :-> 8 Calculate the minimum cost/ distance the main part of the optimisation

# %%
list_dist_final = []

for item in full_tree:
    add_dist = 0
    print(item[0])
    for k in item[1:]:
        for var in k:
            name_ =  var[0]
            lat_ = var[1]
            lon_ = var[2]
            print("POI => ",name_," ",lat_," ",lon_)
            # sub
            
            for item_ in full_tree:
                if(item_[0]!=item[0]):
                    for k_ in item_[1:]:
                        for var_ in k_:
                            name__ =  var_[0]
                            lat__ = var_[1]
                            lon__ = var_[2]
                            print(name__," ",lat__," ",lon__,end="")
                            dis = ret_dist(lat_,lon_,lat__,lon__)
                            print(" dist => ",dis)
                            add_dist += dis
            print("ADD DIST =====> ",add_dist)
            list_dist_final.append([item[0],name_,add_dist,[lat_,lon_]])
# Out:
# Meat
# POI =>  Khasi   22.569098   88.366418
# My Tea   22.582298   88.367218 dist =>  1.4705310693205238
# museum1   22.570298   88.352218 dist =>  1.4645926186841736
# museum2   22.492298   88.362218 dist =>  8.553342738827284
# museum3   22.592298   88.307218 dist =>  6.6049750985927815
# Indo China   22.542298   88.397218 dist =>  4.346941214152579
# My Thai   22.535298   88.397218 dist =>  4.9137195915993095
# Thaism   22.535298   88.387218 dist =>  4.324312604507568
# Nilu Thai   22.538298   88.396218 dist =>  4.594264024099124
# NSCB   22.338298   88.333218 dist =>  25.897708762440658
# DODO Fishery   22.738298   88.696218 dist =>  38.73305823304252
# Baloo's Dhaba   22.608298   88.437218 dist =>  8.478092248138596
# ADD DIST =====>  109.38153820340513
# POI =>  Chasi   22.562298   88.376218
# My Tea   22.582298   88.367218 dist =>  2.4090067298288873
# museum1   22.570298   88.352218 dist =>  2.6208140300702207
# museum2   22.492298   88.362218 dist =>  7.917837977506495
# museum3   22.592298   88.307218 dist =>  7.832996883255212
# Indo China   22.542298   88.397218 dist =>  3.0987684226633543
# My Thai   22.535298   88.397218 dist =>  3.6977039776113134
# Thaism   22.535298   88.387218 dist =>  3.2087580769447075
# Nilu Thai   22.538298   88.396218 dist =>  3.3685800872732967
# NSCB   22.338298   88.333218 dist =>  25.304567126575012
# DODO Fishery   22.738298   88.696218 dist =>  38.239336837795115
# Baloo's Dhaba   22.608298   88.437218 dist =>  8.088595670525862
# ADD DIST =====>  215.16850402345466
# Tea
# POI =>  My Tea   22.582298   88.367218
# Khasi   22.569098   88.366418 dist =>  1.4705310693205238
# Chasi   22.562298   88.376218 dist =>  2.4090067298288873
# museum1   22.570298   88.352218 dist =>  2.038383021097454
# museum2   22.492298   88.362218 dist =>  10.023855401720926
# museum3   22.592298   88.307218 dist =>  6.261466783978278
# Indo China   22.542298   88.397218 dist =>  5.412111874555188
# My Thai   22.535298   88.397218 dist =>  6.068445506471385
# Thaism   22.535298   88.387218 dist =>  5.616975270900324
# Nilu Thai   22.538298   88.396218 dist =>  5.729375020785105
# NSCB   22.338298   88.333218 dist =>  27.364182838226505
# DODO Fishery   22.738298   88.696218 dist =>  37.966803876543516
# Baloo's Dhaba   22.608298   88.437218 dist =>  7.748368652645731
# ADD DIST =====>  118.10950604607383
# Museum
# POI =>  museum1   22.570298   88.352218
# Khasi   22.569098   88.366418 dist =>  1.4645926186841736
# Chasi   22.562298   88.376218 dist =>  2.6208140300702207
# My Tea   22.582298   88.367218 dist =>  2.038383021097454
# Indo China   22.542298   88.397218 dist =>  5.57375481564185
# My Thai   22.535298   88.397218 dist =>  6.043501637693017
# Thaism   22.535298   88.387218 dist =>  5.29926277739444
# Nilu Thai   22.538298   88.396218 dist =>  5.753046037645829
# NSCB   22.338298   88.333218 dist =>  25.87912979842834
# DODO Fishery   22.738298   88.696218 dist =>  39.95055915851938
# Baloo's Dhaba   22.608298   88.437218 dist =>  9.69867252198896
# ADD DIST =====>  104.32171641716366
# POI =>  museum2   22.492298   88.362218
# Khasi   22.569098   88.366418 dist =>  8.553342738827284
# Chasi   22.562298   88.376218 dist =>  7.917837977506495
# My Tea   22.582298   88.367218 dist =>  10.023855401720926
# Indo China   22.542298   88.397218 dist =>  6.62293214017525
# My Thai   22.535298   88.397218 dist =>  5.984117655630972
# Thaism   22.535298   88.387218 dist =>  5.429069224067849
# Nilu Thai   22.538298   88.396218 dist =>  6.195501038326321
# NSCB   22.338298   88.333218 dist =>  17.387011049142743
# DODO Fishery   22.738298   88.696218 dist =>  43.87247613586244
# Baloo's Dhaba   22.608298   88.437218 dist =>  15.027862818141001
# ADD DIST =====>  231.3357225965649
# POI =>  museum3   22.592298   88.307218
# Khasi   22.569098   88.366418 dist =>  6.6049750985927815
# Chasi   22.562298   88.376218 dist =>  7.832996883255212
# My Tea   22.582298   88.367218 dist =>  6.261466783978278
# Indo China   22.542298   88.397218 dist =>  10.78817358778862
# My Thai   22.535298   88.397218 dist =>  11.209625786239236
# Thaism   22.535298   88.387218 dist =>  10.378820049105906
# Nilu Thai   22.538298   88.396218 dist =>  10.938256585830558
# NSCB   22.338298   88.333218 dist =>  28.37849745679055
# DODO Fishery   22.738298   88.696218 dist =>  43.10307298355485
# Baloo's Dhaba   22.608298   88.437218 dist =>  13.467583844484045
# ADD DIST =====>  380.29919165618503
# Chinese Res
# POI =>  Indo China   22.542298   88.397218
# Khasi   22.569098   88.366418 dist =>  4.346941214152579
# Chasi   22.562298   88.376218 dist =>  3.0987684226633543
# My Tea   22.582298   88.367218 dist =>  5.412111874555188
# museum1   22.570298   88.352218 dist =>  5.57375481564185
# museum2   22.492298   88.362218 dist =>  6.62293214017525
# museum3   22.592298   88.307218 dist =>  10.78817358778862
# My Thai   22.535298   88.397218 dist =>  0.7786088326069296
# Thaism   22.535298   88.387218 dist =>  1.2890545514893508
# Nilu Thai   22.538298   88.396218 dist =>  0.4566259768111724
# NSCB   22.338298   88.333218 dist =>  23.62558415830091
# DODO Fishery   22.738298   88.696218 dist =>  37.64915684024951
# Baloo's Dhaba   22.608298   88.437218 dist =>  8.41253251587534
# ADD DIST =====>  108.05424493031006
# Thai Res
# POI =>  My Thai   22.535298   88.397218
# Khasi   22.569098   88.366418 dist =>  4.9137195915993095
# Chasi   22.562298   88.376218 dist =>  3.6977039776113134
# My Tea   22.582298   88.367218 dist =>  6.068445506471385
# museum1   22.570298   88.352218 dist =>  6.043501637693017
# museum2   22.492298   88.362218 dist =>  5.984117655630972
# museum3   22.592298   88.307218 dist =>  11.209625786239236
# Indo China   22.542298   88.397218 dist =>  0.7786088326069296
# NSCB   22.338298   88.333218 dist =>  22.87885484354797
# DODO Fishery   22.738298   88.696218 dist =>  38.10593292546749
# Baloo's Dhaba   22.608298   88.437218 dist =>  9.099977455838893
# ADD DIST =====>  108.78048821270652
# POI =>  Thaism   22.535298   88.387218
# Khasi   22.569098   88.366418 dist =>  4.324312604507568
# Chasi   22.562298   88.376218 dist =>  3.2087580769447075
# My Tea   22.582298   88.367218 dist =>  5.616975270900324
# museum1   22.570298   88.352218 dist =>  5.29926277739444
# museum2   22.492298   88.362218 dist =>  5.429069224067849
# museum3   22.592298   88.307218 dist =>  10.378820049105906
# Indo China   22.542298   88.397218 dist =>  1.2890545514893508
# NSCB   22.338298   88.333218 dist =>  22.604636140492765
# DODO Fishery   22.738298   88.696218 dist =>  38.937653512062525
# Baloo's Dhaba   22.608298   88.437218 dist =>  9.60749256290888
# ADD DIST =====>  215.47652298258086
# POI =>  Nilu Thai   22.538298   88.396218
# Khasi   22.569098   88.366418 dist =>  4.594264024099124
# Chasi   22.562298   88.376218 dist =>  3.3685800872732967
# My Tea   22.582298   88.367218 dist =>  5.729375020785105
# museum1   22.570298   88.352218 dist =>  5.753046037645829
# museum2   22.492298   88.362218 dist =>  6.195501038326321
# museum3   22.592298   88.307218 dist =>  10.938256585830558
# Indo China   22.542298   88.397218 dist =>  0.4566259768111724
# NSCB   22.338298   88.333218 dist =>  23.16967546653363
# DODO Fishery   22.738298   88.696218 dist =>  37.99206019044623
# Baloo's Dhaba   22.608298   88.437218 dist =>  8.851896555319634
# ADD DIST =====>  322.52580396565173
# Airport
# POI =>  NSCB   22.338298   88.333218
# Khasi   22.569098   88.366418 dist =>  25.897708762440658
# Chasi   22.562298   88.376218 dist =>  25.304567126575012
# My Tea   22.582298   88.367218 dist =>  27.364182838226505
# museum1   22.570298   88.352218 dist =>  25.87912979842834
# museum2   22.492298   88.362218 dist =>  17.387011049142743
# museum3   22.592298   88.307218 dist =>  28.37849745679055
# Indo China   22.542298   88.397218 dist =>  23.62558415830091
# My Thai   22.535298   88.397218 dist =>  22.87885484354797
# Thaism   22.535298   88.387218 dist =>  22.604636140492765
# Nilu Thai   22.538298   88.396218 dist =>  23.16967546653363
# DODO Fishery   22.738298   88.696218 dist =>  58.05396117896989
# Baloo's Dhaba   22.608298   88.437218 dist =>  31.877695905737227
# ADD DIST =====>  332.4215047251862
# Fishery
# POI =>  DODO Fishery   22.738298   88.696218
# Khasi   22.569098   88.366418 dist =>  38.73305823304252
# Chasi   22.562298   88.376218 dist =>  38.239336837795115
# My Tea   22.582298   88.367218 dist =>  37.966803876543516
# museum1   22.570298   88.352218 dist =>  39.95055915851938
# museum2   22.492298   88.362218 dist =>  43.87247613586244
# museum3   22.592298   88.307218 dist =>  43.10307298355485
# Indo China   22.542298   88.397218 dist =>  37.64915684024951
# My Thai   22.535298   88.397218 dist =>  38.10593292546749
# Thaism   22.535298   88.387218 dist =>  38.937653512062525
# Nilu Thai   22.538298   88.396218 dist =>  37.99206019044623
# NSCB   22.338298   88.333218 dist =>  58.05396117896989
# Baloo's Dhaba   22.608298   88.437218 dist =>  30.260497152616665
# ADD DIST =====>  482.86456902513015
# Motel
# POI =>  Baloo's Dhaba   22.608298   88.437218
# Khasi   22.569098   88.366418 dist =>  8.478092248138596
# Chasi   22.562298   88.376218 dist =>  8.088595670525862
# My Tea   22.582298   88.367218 dist =>  7.748368652645731
# museum1   22.570298   88.352218 dist =>  9.69867252198896
# museum2   22.492298   88.362218 dist =>  15.027862818141001
# museum3   22.592298   88.307218 dist =>  13.467583844484045
# Indo China   22.542298   88.397218 dist =>  8.41253251587534
# My Thai   22.535298   88.397218 dist =>  9.099977455838893
# Thaism   22.535298   88.387218 dist =>  9.60749256290888
# Nilu Thai   22.538298   88.396218 dist =>  8.851896555319634
# NSCB   22.338298   88.333218 dist =>  31.877695905737227
# DODO Fishery   22.738298   88.696218 dist =>  30.260497152616665
# ADD DIST =====>  160.61926790422083

# %% [markdown]
# # Procedure :-> 9 Show the minimum distance calculated from the matrix

# %%
list_dist_final
# Out:
# [['Meat', 'Khasi', 109.38153820340513, [22.569098, 88.366418]],
#  ['Meat', 'Chasi', 215.16850402345466, [22.562298, 88.376218]],
#  ['Tea', 'My Tea', 118.10950604607383, [22.582298, 88.367218]],
#  ['Museum', 'museum1', 104.32171641716366, [22.570298, 88.352218]],
#  ['Museum', 'museum2', 231.3357225965649, [22.492298, 88.362218]],
#  ['Museum', 'museum3', 380.29919165618503, [22.592298, 88.307218]],
#  ['Chinese Res', 'Indo China', 108.05424493031006, [22.542298, 88.397218]],
#  ['Thai Res', 'My Thai', 108.78048821270652, [22.535298, 88.397218]],
#  ['Thai Res', 'Thaism', 215.47652298258086, [22.535298, 88.387218]],
#  ['Thai Res', 'Nilu Thai', 322.52580396565173, [22.538298, 88.396218]],
#  ['Airport', 'NSCB', 332.4215047251862, [22.338298, 88.333218]],
#  ['Fishery', 'DODO Fishery', 482.86456902513015, [22.738298, 88.696218]],
#  ['Motel', "Baloo's Dhaba", 160.61926790422083, [22.608298, 88.437218]]]

# %% [markdown]
# # Procedure :-> 10 Getting the minimum distance cluster, the next part of the algorithm

# %%
# getting unique categories
name_it = list_dist_final[0][0]
min_ = list_dist_final[0][2]


fin_opt_list = []
for item in list_dist_final:
    if(name_it==item[0]):
        if(min_>=item[2]):
            cat_op = item[0]
            min_ = item[2]
            op_name = item[1]
            lat_lon = item[3:]
    if(name_it!=item[0]):
        fin_opt_list.append([cat_op,min_,op_name,lat_lon])
        min_ = item[2]
        name_it = item[0]
        cat_op = item[0]
        op_name = item[1]
        lat_lon = item[3:]
fin_opt_list.append([cat_op,min_,op_name,lat_lon])
print(fin_opt_list)
# Out:
# [['Meat', 109.38153820340513, 'Khasi', [[22.569098, 88.366418]]], ['Tea', 118.10950604607383, 'My Tea', [[22.582298, 88.367218]]], ['Museum', 104.32171641716366, 'museum1', [[22.570298, 88.352218]]], ['Chinese Res', 108.05424493031006, 'Indo China', [[22.542298, 88.397218]]], ['Thai Res', 108.78048821270652, 'My Thai', [[22.535298, 88.397218]]], ['Airport', 332.4215047251862, 'NSCB', [[22.338298, 88.333218]]], ['Fishery', 482.86456902513015, 'DODO Fishery', [[22.738298, 88.696218]]], ['Motel', 160.61926790422083, "Baloo's Dhaba", [[22.608298, 88.437218]]]]

# %% [markdown]
# # Procedure :-> 11   Show the most optimised cluster

# %%
import pandas as pd 

latitude =  22.569098
longitude = 88.366418

F_MAP = folium.Map(location=[latitude, longitude],tiles="Stamen Toner", zoom_start=11)
for i in fin_opt_list:
    for j in fin_opt_list:
        p1 = i[3]
        p2 = j[3]
        #print(p1[0])
        #print(p2[0])
        folium.PolyLine(locations=[p1[0], p2[0]], color='red',weight=1.5,opacity=1).add_to(F_MAP)
F_MAP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
name=map_data[0][0]
for item in map_data:
    lat = item[2]
    lng = item[3]
    print(item," => ")
    if(item[0]!=name):
        OVER_COL = str(get_random_col())
        FILL_COL = str(get_random_col())
        name = item[0]
    label = "cat : {}, Name : {}".format(item[0],item[1])
    folium.CircleMarker(
                        [lat, lng],
                        radius=5,
                        popup=label,
                        color=OVER_COL,
                        fill=True,
                        fill_color=FILL_COL,
                        fill_opacity=0.7).add_to(F_MAP)
F_MAP
# Out:
# ('Meat', 'Khasi', 22.569098, 88.366418)  =>
# ('Meat', 'Chasi', 22.562298, 88.376218)  =>
# ('Tea', 'My Tea', 22.582298, 88.367218)  =>
# ('Museum', 'museum1', 22.570298, 88.352218)  =>
# ('Museum', 'museum2', 22.492298, 88.362218)  =>
# ('Museum', 'museum3', 22.592298, 88.307218)  =>
# ('Chinese Res', 'Indo China', 22.542298, 88.397218)  =>
# ('Thai Res', 'My Thai', 22.535298, 88.397218)  =>
# ('Thai Res', 'Thaism', 22.535298, 88.387218)  =>
# ('Thai Res', 'Nilu Thai', 22.538298, 88.396218)  =>
# ('Airport', 'NSCB', 22.338298, 88.333218)  =>
# ('Fishery', 'DODO Fishery', 22.738298, 88.696218)  =>
# ('Motel', "Baloo's Dhaba", 22.608298, 88.437218)  =>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(52.2296756)
lon1 = radians(21.0122287)
lat2 = radians(52.406374)
lon2 = radians(16.9251681)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
print("Should be:", 278.546, "km")
# Out:
# Result: 278.54558935106695
# Should be: 278.546 km
