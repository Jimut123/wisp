# %%
"""
Algorithm:
    Find the addition of distance from every point to 
    to every other point except their class and select the minimum from their class.
"""


from math import sin, cos, sqrt, atan2, radians
import random # library for random number generation
import folium # plotting library

# approximate radius of earth in km
R = 6373.0

def ret_dist(lat1,lon1,lat2,lon2):
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    #print("Result:", distance)
    #print("Should be:", 278.546, "km")
    return distance
string_gen = "0123456789abcdef"
def get_random_col():
    # unnecessary stuffs to make the visualization cool
    ret_str = "#"
    for i in range(6):
        ret_str += random.choice(string_gen)
    return ret_str
latitude =  22.569098
longitude = 88.366418


def JimutCluster1(map_data):
    MAP = folium.Map(location=[latitude, longitude],tiles="Stamen Toner", zoom_start=11)

    name=map_data[0][0]

    full_tree = []
    data_cate = []
    OVER_COL = str(get_random_col())
    FILL_COL = str(get_random_col())
    for item in map_data:
        lat = item[2]
        lng = item[3]
        #print(item," => ")
        if(item[0]!=name):
            OVER_COL = str(get_random_col())
            FILL_COL = str(get_random_col())
            full_tree.append([name,data_cate])
            name=item[0]
            data_cate=[]
            #print("got into first check")
        if(item[0]==name):
            data_cate.append([item[1],lat,lng])
            #print("got into 2nd check")
        label = "cat : {}, Name : {}".format(item[0],item[1])
        folium.CircleMarker(
                            [lat, lng],
                            radius=5,
                            popup=label,
                            color=OVER_COL,
                            fill=True,
                            fill_color=FILL_COL,
                            fill_opacity=0.7).add_to(MAP)
    full_tree.append([name,data_cate])
    
    min_dist_vert = []
    for i in full_tree:
        item_class = i[0]
        print(item_class)
        k_dummy=0
        print("i[1:][0] => ",i[1:][0])
        for item in i[1:][0]:
            # the upper class 
            name_point_ = item[0]
            name_lat_ = item[1]
            name_lon_ = item[2]

            final_dist=0
            print("item loop => ",name_point_," == ",name_lat_," == ",name_lon_)
            #if len(min_dist_vert) == 0:
            for k in full_tree:
                # the sub class
                item_class2 = k[0]
                #print("class 2 => ",item_class2)
                if item_class2!=item_class:
                    #print("class 2 ",k)
                    for j in k[1:][0]:
                        name_point = j[0]
                        name_lat = j[1]
                        name_lon = j[2]
                        print(name_point," == ",name_lat," == ",name_lon,end="")
                        dist_from_item = ret_dist(name_lat_,name_lon_,name_lat,name_lon)
                        print(" dist from ",name_point_," to ",name_point," is:=> ",dist_from_item)
                        final_dist += dist_from_item
            print("Total dist of ",name_point_," is => ",final_dist)

            if k_dummy==1:
                if minimum_dist>=final_dist:
                    minimum_dist = final_dist
                    min_dist_lat = name_lat_
                    min_dist_lon = name_lon_
                    min_dist_name = name_point_
                    print("Minimum => ",min_dist_name,"dist => ",minimum_dist," + ",min_dist_lat," + ",min_dist_lon)
            if k_dummy==0:
                minimum_dist=final_dist
                minimum_dist = final_dist
                min_dist_lat = name_lat_
                min_dist_lon = name_lon_
                min_dist_name = name_point_
                k_dummy=1
                print("dummy set to 1")
            print("$$$$Minimum => ",min_dist_name,"dist => ",minimum_dist," + ",min_dist_lat," + ",min_dist_lon)
        min_dist_vert.append([min_dist_name,[min_dist_lat,min_dist_lon]])
        print("MIN DIST VERT LIST => ",min_dist_vert)
    for i1 in min_dist_vert:
        for j1 in min_dist_vert:
            p1 = i1[1]
            p2 = j1[1]
            print(p1,",",p2)
            folium.PolyLine(locations=[p1, p2], color='red',weight=1.5,opacity=1).add_to(MAP)
    return MAP

# %%
map_data = [("Meat","Khasi",22.569098,88.366418),
            ("Meat","Chasi",22.562298,88.376218),
            ("Tea","My Tea",22.582298,88.367218),
            ("Museum","museum1",22.570298,88.352218),
            ("Museum","museum2",22.492298,88.362218),
            ("Museum","museum3",22.592298,88.307218),
            ("Chinese Res","Indo China",22.542298,88.397218),
            ("Thai Res","My Thai",22.505298,88.397218),
            ("Thai Res","Thaism",22.535298,88.387218),
            ("Thai Res","Nilu Thai",22.538298,88.396218)]
"""
            ("Airport","NSCB",22.338298,88.333218),
            ("Fishery","DODO Fishery",22.738298,88.696218),
            ("Motel","Baloo's Dhaba",22.608298,88.437218)
           ]
"""
F = JimutCluster1(map_data)
F
# Out:
# Meat
# i[1:][0] =>  [['Khasi', 22.569098, 88.366418], ['Chasi', 22.562298, 88.376218]]
# item loop =>  Khasi  ==  22.569098  ==  88.366418
# My Tea  ==  22.582298  ==  88.367218 dist from  Khasi  to  My Tea  is:=>  1.4705310693205238
# museum1  ==  22.570298  ==  88.352218 dist from  Khasi  to  museum1  is:=>  1.4645926186841736
# museum2  ==  22.492298  ==  88.362218 dist from  Khasi  to  museum2  is:=>  8.553342738827284
# museum3  ==  22.592298  ==  88.307218 dist from  Khasi  to  museum3  is:=>  6.6049750985927815
# Indo China  ==  22.542298  ==  88.397218 dist from  Khasi  to  Indo China  is:=>  4.346941214152579
# My Thai  ==  22.505298  ==  88.397218 dist from  Khasi  to  My Thai  is:=>  7.769958372876383
# Thaism  ==  22.535298  ==  88.387218 dist from  Khasi  to  Thaism  is:=>  4.324312604507568
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  Khasi  to  Nilu Thai  is:=>  4.594264024099124
# Total dist of  Khasi  is =>  39.12891774106042
# dummy set to 1
# $$$$Minimum =>  Khasi dist =>  39.12891774106042  +  22.569098  +  88.366418
# item loop =>  Chasi  ==  22.562298  ==  88.376218
# My Tea  ==  22.582298  ==  88.367218 dist from  Chasi  to  My Tea  is:=>  2.4090067298288873
# museum1  ==  22.570298  ==  88.352218 dist from  Chasi  to  museum1  is:=>  2.6208140300702207
# museum2  ==  22.492298  ==  88.362218 dist from  Chasi  to  museum2  is:=>  7.917837977506495
# museum3  ==  22.592298  ==  88.307218 dist from  Chasi  to  museum3  is:=>  7.832996883255212
# Indo China  ==  22.542298  ==  88.397218 dist from  Chasi  to  Indo China  is:=>  3.0987684226633543
# My Thai  ==  22.505298  ==  88.397218 dist from  Chasi  to  My Thai  is:=>  6.697137952695561
# Thaism  ==  22.535298  ==  88.387218 dist from  Chasi  to  Thaism  is:=>  3.2087580769447075
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  Chasi  to  Nilu Thai  is:=>  3.3685800872732967
# Total dist of  Chasi  is =>  37.15390016023773
# Minimum =>  Chasi dist =>  37.15390016023773  +  22.562298  +  88.376218
# $$$$Minimum =>  Chasi dist =>  37.15390016023773  +  22.562298  +  88.376218
# MIN DIST VERT LIST =>  [['Chasi', [22.562298, 88.376218]]]
# Tea
# i[1:][0] =>  [['My Tea', 22.582298, 88.367218]]
# item loop =>  My Tea  ==  22.582298  ==  88.367218
# Khasi  ==  22.569098  ==  88.366418 dist from  My Tea  to  Khasi  is:=>  1.4705310693205238
# Chasi  ==  22.562298  ==  88.376218 dist from  My Tea  to  Chasi  is:=>  2.4090067298288873
# museum1  ==  22.570298  ==  88.352218 dist from  My Tea  to  museum1  is:=>  2.038383021097454
# museum2  ==  22.492298  ==  88.362218 dist from  My Tea  to  museum2  is:=>  10.023855401720926
# museum3  ==  22.592298  ==  88.307218 dist from  My Tea  to  museum3  is:=>  6.261466783978278
# Indo China  ==  22.542298  ==  88.397218 dist from  My Tea  to  Indo China  is:=>  5.412111874555188
# My Thai  ==  22.505298  ==  88.397218 dist from  My Tea  to  My Thai  is:=>  9.102319290027394
# Thaism  ==  22.535298  ==  88.387218 dist from  My Tea  to  Thaism  is:=>  5.616975270900324
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  My Tea  to  Nilu Thai  is:=>  5.729375020785105
# Total dist of  My Tea  is =>  48.064024462214086
# dummy set to 1
# $$$$Minimum =>  My Tea dist =>  48.064024462214086  +  22.582298  +  88.367218
# MIN DIST VERT LIST =>  [['Chasi', [22.562298, 88.376218]], ['My Tea', [22.582298, 88.367218]]]
# Museum
# i[1:][0] =>  [['museum1', 22.570298, 88.352218], ['museum2', 22.492298, 88.362218], ['museum3', 22.592298, 88.307218]]
# item loop =>  museum1  ==  22.570298  ==  88.352218
# Khasi  ==  22.569098  ==  88.366418 dist from  museum1  to  Khasi  is:=>  1.4645926186841736
# Chasi  ==  22.562298  ==  88.376218 dist from  museum1  to  Chasi  is:=>  2.6208140300702207
# My Tea  ==  22.582298  ==  88.367218 dist from  museum1  to  My Tea  is:=>  2.038383021097454
# Indo China  ==  22.542298  ==  88.397218 dist from  museum1  to  Indo China  is:=>  5.57375481564185
# My Thai  ==  22.505298  ==  88.397218 dist from  museum1  to  My Thai  is:=>  8.581653815176928
# Thaism  ==  22.535298  ==  88.387218 dist from  museum1  to  Thaism  is:=>  5.29926277739444
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  museum1  to  Nilu Thai  is:=>  5.753046037645829
# Total dist of  museum1  is =>  31.33150711571089
# dummy set to 1
# $$$$Minimum =>  museum1 dist =>  31.33150711571089  +  22.570298  +  88.352218
# item loop =>  museum2  ==  22.492298  ==  88.362218
# Khasi  ==  22.569098  ==  88.366418 dist from  museum2  to  Khasi  is:=>  8.553342738827284
# Chasi  ==  22.562298  ==  88.376218 dist from  museum2  to  Chasi  is:=>  7.917837977506495
# My Tea  ==  22.582298  ==  88.367218 dist from  museum2  to  My Tea  is:=>  10.023855401720926
# Indo China  ==  22.542298  ==  88.397218 dist from  museum2  to  Indo China  is:=>  6.62293214017525
# My Thai  ==  22.505298  ==  88.397218 dist from  museum2  to  My Thai  is:=>  3.876516976209208
# Thaism  ==  22.535298  ==  88.387218 dist from  museum2  to  Thaism  is:=>  5.429069224067849
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  museum2  to  Nilu Thai  is:=>  6.195501038326321
# Total dist of  museum2  is =>  48.61905549683333
# $$$$Minimum =>  museum1 dist =>  31.33150711571089  +  22.570298  +  88.352218
# item loop =>  museum3  ==  22.592298  ==  88.307218
# Khasi  ==  22.569098  ==  88.366418 dist from  museum3  to  Khasi  is:=>  6.6049750985927815
# Chasi  ==  22.562298  ==  88.376218 dist from  museum3  to  Chasi  is:=>  7.832996883255212
# My Tea  ==  22.582298  ==  88.367218 dist from  museum3  to  My Tea  is:=>  6.261466783978278
# Indo China  ==  22.542298  ==  88.397218 dist from  museum3  to  Indo China  is:=>  10.78817358778862
# My Thai  ==  22.505298  ==  88.397218 dist from  museum3  to  My Thai  is:=>  13.383633718960384
# Thaism  ==  22.535298  ==  88.387218 dist from  museum3  to  Thaism  is:=>  10.378820049105906
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  museum3  to  Nilu Thai  is:=>  10.938256585830558
# Total dist of  museum3  is =>  66.18832270751173
# $$$$Minimum =>  museum1 dist =>  31.33150711571089  +  22.570298  +  88.352218
# MIN DIST VERT LIST =>  [['Chasi', [22.562298, 88.376218]], ['My Tea', [22.582298, 88.367218]], ['museum1', [22.570298, 88.352218]]]
# Chinese Res
# i[1:][0] =>  [['Indo China', 22.542298, 88.397218]]
# item loop =>  Indo China  ==  22.542298  ==  88.397218
# Khasi  ==  22.569098  ==  88.366418 dist from  Indo China  to  Khasi  is:=>  4.346941214152579
# Chasi  ==  22.562298  ==  88.376218 dist from  Indo China  to  Chasi  is:=>  3.0987684226633543
# My Tea  ==  22.582298  ==  88.367218 dist from  Indo China  to  My Tea  is:=>  5.412111874555188
# museum1  ==  22.570298  ==  88.352218 dist from  Indo China  to  museum1  is:=>  5.57375481564185
# museum2  ==  22.492298  ==  88.362218 dist from  Indo China  to  museum2  is:=>  6.62293214017525
# museum3  ==  22.592298  ==  88.307218 dist from  Indo China  to  museum3  is:=>  10.78817358778862
# My Thai  ==  22.505298  ==  88.397218 dist from  Indo China  to  My Thai  is:=>  4.115503829495035
# Thaism  ==  22.535298  ==  88.387218 dist from  Indo China  to  Thaism  is:=>  1.2890545514893508
# Nilu Thai  ==  22.538298  ==  88.396218 dist from  Indo China  to  Nilu Thai  is:=>  0.4566259768111724
# Total dist of  Indo China  is =>  41.7038664127724
# dummy set to 1
# $$$$Minimum =>  Indo China dist =>  41.7038664127724  +  22.542298  +  88.397218
# MIN DIST VERT LIST =>  [['Chasi', [22.562298, 88.376218]], ['My Tea', [22.582298, 88.367218]], ['museum1', [22.570298, 88.352218]], ['Indo China', [22.542298, 88.397218]]]
# Thai Res
# i[1:][0] =>  [['My Thai', 22.505298, 88.397218], ['Thaism', 22.535298, 88.387218], ['Nilu Thai', 22.538298, 88.396218]]
# item loop =>  My Thai  ==  22.505298  ==  88.397218
# Khasi  ==  22.569098  ==  88.366418 dist from  My Thai  to  Khasi  is:=>  7.769958372876383
# Chasi  ==  22.562298  ==  88.376218 dist from  My Thai  to  Chasi  is:=>  6.697137952695561
# My Tea  ==  22.582298  ==  88.367218 dist from  My Thai  to  My Tea  is:=>  9.102319290027394
# museum1  ==  22.570298  ==  88.352218 dist from  My Thai  to  museum1  is:=>  8.581653815176928
# museum2  ==  22.492298  ==  88.362218 dist from  My Thai  to  museum2  is:=>  3.876516976209208
# museum3  ==  22.592298  ==  88.307218 dist from  My Thai  to  museum3  is:=>  13.383633718960384
# Indo China  ==  22.542298  ==  88.397218 dist from  My Thai  to  Indo China  is:=>  4.115503829495035
# Total dist of  My Thai  is =>  53.52672395544089
# dummy set to 1
# $$$$Minimum =>  My Thai dist =>  53.52672395544089  +  22.505298  +  88.397218
# item loop =>  Thaism  ==  22.535298  ==  88.387218
# Khasi  ==  22.569098  ==  88.366418 dist from  Thaism  to  Khasi  is:=>  4.324312604507568
# Chasi  ==  22.562298  ==  88.376218 dist from  Thaism  to  Chasi  is:=>  3.2087580769447075
# My Tea  ==  22.582298  ==  88.367218 dist from  Thaism  to  My Tea  is:=>  5.616975270900324
# museum1  ==  22.570298  ==  88.352218 dist from  Thaism  to  museum1  is:=>  5.29926277739444
# museum2  ==  22.492298  ==  88.362218 dist from  Thaism  to  museum2  is:=>  5.429069224067849
# museum3  ==  22.592298  ==  88.307218 dist from  Thaism  to  museum3  is:=>  10.378820049105906
# Indo China  ==  22.542298  ==  88.397218 dist from  Thaism  to  Indo China  is:=>  1.2890545514893508
# Total dist of  Thaism  is =>  35.546252554410145
# Minimum =>  Thaism dist =>  35.546252554410145  +  22.535298  +  88.387218
# $$$$Minimum =>  Thaism dist =>  35.546252554410145  +  22.535298  +  88.387218
# item loop =>  Nilu Thai  ==  22.538298  ==  88.396218
# Khasi  ==  22.569098  ==  88.366418 dist from  Nilu Thai  to  Khasi  is:=>  4.594264024099124
# Chasi  ==  22.562298  ==  88.376218 dist from  Nilu Thai  to  Chasi  is:=>  3.3685800872732967
# My Tea  ==  22.582298  ==  88.367218 dist from  Nilu Thai  to  My Tea  is:=>  5.729375020785105
# museum1  ==  22.570298  ==  88.352218 dist from  Nilu Thai  to  museum1  is:=>  5.753046037645829
# museum2  ==  22.492298  ==  88.362218 dist from  Nilu Thai  to  museum2  is:=>  6.195501038326321
# museum3  ==  22.592298  ==  88.307218 dist from  Nilu Thai  to  museum3  is:=>  10.938256585830558
# Indo China  ==  22.542298  ==  88.397218 dist from  Nilu Thai  to  Indo China  is:=>  0.4566259768111724
# Total dist of  Nilu Thai  is =>  37.03564877077141
# $$$$Minimum =>  Thaism dist =>  35.546252554410145  +  22.535298  +  88.387218
# MIN DIST VERT LIST =>  [['Chasi', [22.562298, 88.376218]], ['My Tea', [22.582298, 88.367218]], ['museum1', [22.570298, 88.352218]], ['Indo China', [22.542298, 88.397218]], ['Thaism', [22.535298, 88.387218]]]
# [22.562298, 88.376218] , [22.562298, 88.376218]
# [22.562298, 88.376218] , [22.582298, 88.367218]
# [22.562298, 88.376218] , [22.570298, 88.352218]
# [22.562298, 88.376218] , [22.542298, 88.397218]
# [22.562298, 88.376218] , [22.535298, 88.387218]
# [22.582298, 88.367218] , [22.562298, 88.376218]
# [22.582298, 88.367218] , [22.582298, 88.367218]
# [22.582298, 88.367218] , [22.570298, 88.352218]
# [22.582298, 88.367218] , [22.542298, 88.397218]
# [22.582298, 88.367218] , [22.535298, 88.387218]
# [22.570298, 88.352218] , [22.562298, 88.376218]
# [22.570298, 88.352218] , [22.582298, 88.367218]
# [22.570298, 88.352218] , [22.570298, 88.352218]
# [22.570298, 88.352218] , [22.542298, 88.397218]
# [22.570298, 88.352218] , [22.535298, 88.387218]
# [22.542298, 88.397218] , [22.562298, 88.376218]
# [22.542298, 88.397218] , [22.582298, 88.367218]
# [22.542298, 88.397218] , [22.570298, 88.352218]
# [22.542298, 88.397218] , [22.542298, 88.397218]
# [22.542298, 88.397218] , [22.535298, 88.387218]
# [22.535298, 88.387218] , [22.562298, 88.376218]
# [22.535298, 88.387218] , [22.582298, 88.367218]
# [22.535298, 88.387218] , [22.570298, 88.352218]
# [22.535298, 88.387218] , [22.542298, 88.397218]
# [22.535298, 88.387218] , [22.535298, 88.387218]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
